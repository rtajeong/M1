# %% [markdown]
# # Web Scraping

# %% [markdown]
# # JSON format
# - json: JavaScript Object Notation (자바 스크립트 객체 표기법)
# - 데이터를 쉽게 '교환' 하고 '저장' 하기 위한 텍스트 기반의 데이터 교환 표준

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import json
from bs4 import BeautifulSoup

# %%
obj = """
{
    "name": "Kim",
    "places_lived": ["Seoul", "Korea"],
    "pet": null, 
    "siblings": [{"name": "Scott", "age":25, "pet":"Zuko"}]
}
"""

# %%
type(obj)
# Out:
# str

# %%
r = json.loads(obj)   # decoding (json --> dict)
type(r)
# Out:
# dict

# %%
json.dumps(r)    # encoding (dict --> json)
# Out:
# '{"name": "Kim", "places_lived": ["Seoul", "Korea"], "pet": null, "siblings": [{"name": "Scott", "age": 25, "pet": "Zuko"}]}'

# %%
# Exercise 2 (from https://rfriend.tistory.com/474)
py_data = {

    "1.FirstName": "Gildong",
    "2.LastName": "Hong",
    "3.Age": 20,
    "4.University": "Hangook University",
    "5.Courses": [
        {
            "Classes": [
                "Probability",
                "Generalized Linear Model",
                "Categorical Data Analysis"
            ],
            "Major": "Statistics"
        },
        {
            "Classes": [
                "Data Structure",
                "Programming",
                "Algorithms"
            ],
            "Minor": "ComputerScience"
        }
    ]
}

# %%
type(py_data)
# Out:
# dict

# %%
py_data.keys()
# py_data.items()
# Out:
# dict_keys(['1.FirstName', '2.LastName', '3.Age', '4.University', '5.Courses'])

# %%
py_data.values()
# Out:
# dict_values(['Gildong', 'Hong', 20, 'Hangook University', [{'Classes': ['Probability', 'Generalized Linear Model', 'Categorical Data Analysis'], 'Major': 'Statistics'}, {'Classes': ['Data Structure', 'Programming', 'Algorithms'], 'Minor': 'ComputerScience'}]])

# %%
py_data['5.Courses']
# Out:
# [{'Classes': ['Probability',
#    'Generalized Linear Model',
#    'Categorical Data Analysis'],
#   'Major': 'Statistics'},
#  {'Classes': ['Data Structure', 'Programming', 'Algorithms'],
#   'Minor': 'ComputerScience'}]

# %%
import json
json_str = json.dumps(py_data)
type(json_str), json_str
# Out:
# (str,
#  '{"1.FirstName": "Gildong", "2.LastName": "Hong", "3.Age": 20, "4.University": "Hangook University", "5.Courses": [{"Classes": ["Probability", "Generalized Linear Model", "Categorical Data Analysis"], "Major": "Statistics"}, {"Classes": ["Data Structure", "Programming", "Algorithms"], "Minor": "ComputerScience"}]}')

# %%
pd.Series(py_data)
# Out:
# 1.FirstName                                               Gildong
# 2.LastName                                                   Hong
# 3.Age                                                          20
# 4.University                                   Hangook University
# 5.Courses       [{'Classes': ['Probability', 'Generalized Line...
# dtype: object

# %%
pd.DataFrame(py_data)
# Out:
#   1.FirstName 2.LastName  3.Age        4.University  \
# 0     Gildong       Hong     20  Hangook University
# 1     Gildong       Hong     20  Hangook University
#
#                                            5.Courses
# 0  {'Classes': ['Probability', 'Generalized Linea...
# 1  {'Classes': ['Data Structure', 'Programming', ...

# %%
pd.DataFrame(py_data).iloc[:,-1]
# Out:
# 0    {'Classes': ['Probability', 'Generalized Linea...
# 1    {'Classes': ['Data Structure', 'Programming', ...
# Name: 5.Courses, dtype: object

# %%
pd.DataFrame.from_dict(py_data)
# Out:
#   1.FirstName 2.LastName  3.Age        4.University  \
# 0     Gildong       Hong     20  Hangook University
# 1     Gildong       Hong     20  Hangook University
#
#                                            5.Courses
# 0  {'Classes': ['Probability', 'Generalized Linea...
# 1  {'Classes': ['Data Structure', 'Programming', ...

# %%
pd.json_normalize(py_data)
# Out:
#   1.FirstName 2.LastName  3.Age        4.University  \
# 0     Gildong       Hong     20  Hangook University
#
#                                            5.Courses
# 0  [{'Classes': ['Probability', 'Generalized Line...

# %%
pd.json_normalize(py_data, "5.Courses")
# Out:
#                                              Classes       Major  \
# 0  [Probability, Generalized Linear Model, Catego...  Statistics
# 1          [Data Structure, Programming, Algorithms]         NaN
#
#              Minor
# 0              NaN
# 1  ComputerScience

# %%
pd.json_normalize(py_data, "5.Courses", ['3.Age'])
# Out:
#                                              Classes       Major  \
# 0  [Probability, Generalized Linear Model, Catego...  Statistics
# 1          [Data Structure, Programming, Algorithms]         NaN
#
#              Minor 3.Age
# 0              NaN    20
# 1  ComputerScience    20

# %% [markdown]
# # json_normalize (data, record_path, meta, ...)
# - data: dict or list of dict
# - record_path : decode 해줘야할 열 지정 [{}, {}, {} ....]
# - meta : decode 하는 열과 동일 차원에 존재하는 열들 중 데이터 프레임에 포함시킬 열 선택

# %%
# JSON exercise3
# from https://pandas.pydata.org/pandas-docs/stable/reference/api/\
#              pandas.io.json.json_normalize.html
data = [{'state': 'Florida', 
         'shortname': 'FL', 
         'info': {'governor': 'Rick Scott'},
         'counties': [{'name': 'Dade', 'population': 12345},
                      {'name': 'Broward', 'population': 40000},
                      {'name': 'Palm Beach', 'population': 60000}]},
        {'state': 'Ohio',
         'shortname': 'OH',
         'info': {'governor': 'John Kasich'},
         'counties': [{'name': 'Summit', 'population': 1234},
                      {'name': 'Cuyahoga', 'population': 1337}]}]

# %%
type(data), len(data)
# Out:
# (list, 2)

# %%
pd.json_normalize(data)
# Out:
#      state shortname                                           counties  \
# 0  Florida        FL  [{'name': 'Dade', 'population': 12345}, {'name...
# 1     Ohio        OH  [{'name': 'Summit', 'population': 1234}, {'nam...
#
#   info.governor
# 0    Rick Scott
# 1   John Kasich

# %%
pd.json_normalize(data, 'counties')
# Out:
#          name  population
# 0        Dade       12345
# 1     Broward       40000
# 2  Palm Beach       60000
# 3      Summit        1234
# 4    Cuyahoga        1337

# %%
pd.json_normalize(data, 'counties', ['state', 'shortname', ['info', 'governor']])
# Out:
#          name  population    state shortname info.governor
# 0        Dade       12345  Florida        FL    Rick Scott
# 1     Broward       40000  Florida        FL    Rick Scott
# 2  Palm Beach       60000  Florida        FL    Rick Scott
# 3      Summit        1234     Ohio        OH   John Kasich
# 4    Cuyahoga        1337     Ohio        OH   John Kasich

# %% [markdown]
# # HTML Parsing
# - before you do this example, try to see and run some example HTML files which are in this directory

# %%
from bs4 import BeautifulSoup

# %%
html_text = """
<html>
<body>
  <h1> reading web page with python </h1>
     <p> page analysis </p>
     <p> page alignment </p>
     <td>some text</td><td></td><td><p>more text</p></td><td>even <p>more text</p></td>
</body>
</html>
"""

# %%
soup = BeautifulSoup(html_text, 'html.parser')
soup
# Out:
# <html>
# <body>
# <h1> reading web page with python </h1>
# <p> page analysis </p>
# <p> page alignment </p>
# <td>some text</td><td></td><td><p>more text</p></td><td>even <p>more text</p></td>
# </body>
# </html>

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
soup.h1
# Out:
# <h1> reading web page with python </h1>

# %%
soup.h1.string.strip()
# Out:
# 'reading web page with python'

# %%
soup.p
# Out:
# <p> page analysis </p>

# %%
soup.p.next_sibling.next_sibling
# Out:
# <p> page alignment </p>

# %%
soup.td.next_sibling.next_sibling
# Out:
# <td><p>more text</p></td>

# %%
print(soup.td.next_sibling, soup.td.next_sibling.string)
# Out:
# <td></td> None

# %%
html_text2 = """
<html>
<body>
  <h1 id="title"> reading web page with python </h1>
     <p id="body"> page analysis </p>
     <p> page alignment </p>
     <td>some text</td><td></td><td><p>more text</p></td><td>even <p>more text</p></td>
     <ul>
         <li><a href = "http://www.naver.com"> naver</a></li>
         <li><a href = "http://www.daum.net"> daum</a></li>
     </ul>
  <div id="xxx">
    <h1> Wiki-books store </h1>
    <ul class="item">
      <li> introduction to game design </li>
      <li> introduction to python </li>
      <li> introduction to web design </li>
    </ul>
  </div>
</body>
</html>
"""

# %%
soup = BeautifulSoup(html_text2, 'html.parser')

# %%
soup
# Out:
# <html>
# <body>
# <h1 id="title"> reading web page with python </h1>
# <p id="body"> page analysis </p>
# <p> page alignment </p>
# <td>some text</td><td></td><td><p>more text</p></td><td>even <p>more text</p></td>
# <ul>
# <li><a href="http://www.naver.com"> naver</a></li>
# <li><a href="http://www.daum.net"> daum</a></li>
# </ul>
# <div id="xxx">
# <h1> Wiki-books store </h1>
# <ul class="item">
# <li> introduction to game design </li>
# <li> introduction to python </li>
# <li> introduction to web design </li>
# </ul>
# </div>
# </body>
# </html>

# %% [markdown]
# ### access by tags

# %%
soup.find(id='title')
# Out:
# <h1 id="title"> reading web page with python </h1>

# %%
soup.find(id='body').string
# Out:
# ' page analysis '

# %%
soup.find_all('p')
# Out:
# [<p id="body"> page analysis </p>,
#  <p> page alignment </p>,
#  <p>more text</p>,
#  <p>more text</p>]

# %%
soup.find_all('li')
# Out:
# [<li><a href="http://www.naver.com"> naver</a></li>,
#  <li><a href="http://www.daum.net"> daum</a></li>,
#  <li> introduction to game design </li>,
#  <li> introduction to python </li>,
#  <li> introduction to web design </li>]

# %%
soup.find_all('li')[0]
# Out:
# <li><a href="http://www.naver.com"> naver</a></li>

# %%
soup.find_all('li')[0].string, soup.find_all('li')[0].attrs
# Out:
# (' naver', {})

# %%
soup.find_all('a')[0]
# Out:
# <a href="http://www.naver.com"> naver</a>

# %%
soup.find_all('a')[0].string, soup.find_all('a')[0].attrs
# Out:
# (' naver', {'href': 'http://www.naver.com'})

# %%
for aa in soup.find_all('a'):
    href = aa.attrs['href']
    text = aa.string
    print (text, "-->", href)
# Out:
#  naver --> http://www.naver.com
#  daum --> http://www.daum.net

# %% [markdown]
# ### access by regular expression

# %%
import re
soup.find_all(re.compile("^p"))   # tags starting with a character 'p'
# Out:
# [<p id="body"> page analysis </p>,
#  <p> page alignment </p>,
#  <p>more text</p>,
#  <p>more text</p>]

# %%
soup.find_all(re.compile("div" ))
# Out:
# [<div id="xxx">
#  <h1> Wiki-books store </h1>
#  <ul class="item">
#  <li> introduction to game design </li>
#  <li> introduction to python </li>
#  <li> introduction to web design </li>
#  </ul>
#  </div>]

# %%
soup.find_all(href=re.compile("^http://"))
# Out:
# [<a href="http://www.naver.com"> naver</a>,
#  <a href="http://www.daum.net"> daum</a>]

# %% [markdown]
# ### access by css (Cascading Style Sheets) selector

# %%
soup.select('h1')    # by tags
# Out:
# [<h1 id="title"> reading web page with python </h1>,
#  <h1> Wiki-books store </h1>]

# %%
soup.select('#xxx')  # by id
# Out:
# [<div id="xxx">
#  <h1> Wiki-books store </h1>
#  <ul class="item">
#  <li> introduction to game design </li>
#  <li> introduction to python </li>
#  <li> introduction to web design </li>
#  </ul>
#  </div>]

# %%
soup.select('.item') # by class name
# Out:
# [<ul class="item">
#  <li> introduction to game design </li>
#  <li> introduction to python </li>
#  <li> introduction to web design </li>
#  </ul>]

# %%
soup.select('div .item')  # multi-components(tag=div, class=item)
# Out:
# [<ul class="item">
#  <li> introduction to game design </li>
#  <li> introduction to python </li>
#  <li> introduction to web design </li>
#  </ul>]

# %%
soup.select_one("#xxx > ul > li")  # hierarchy (child)
# Out:
# <li> introduction to game design </li>

# %%
soup.select("div li")   # hierarchy (div tag >>> ul tag) (descendants)
# Out:
# [<li> introduction to game design </li>,
#  <li> introduction to python </li>,
#  <li> introduction to web design </li>]

# %%
text = '<p class="body strikeout"></p>'

css_soup = BeautifulSoup(text, 'html.parser')
css_soup.find_all("p", class_="strikeout")  # can have multiple values for a class
# Out:
# [<p class="body strikeout"></p>]

# %%
css_soup.find_all("p", class_="body")
# Out:
# [<p class="body strikeout"></p>]

# %%
# If you want to search for tags that match two or more CSS classes, 
# you should use a CSS selector:
css_soup.select("p.body.strikeout")
# Out:
# [<p class="body strikeout"></p>]

# %% [markdown]
# # Example from JOBKOREA
# - newly added in 2022.9.21
# - kr.indeed.com (search for 'data science', 'seoul', 'python')

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# search for 'data science', 'seoul', and 'python' in JobaKorea
url = 'https://www.jobkorea.co.kr/Search/?stext=data%20science&dkwrd=10001012776'
link = requests.get(url)
soup = BeautifulSoup(link.text, 'html.parser')

# %%
link.status_code
# Out:
# 200

# %%
soup.select('.recruit-info')
# Out:
# [<div class="recruit-info" style="">
#  <div class="list-filter-wrap">
#  <p class="filter-text">총 <strong class="dev_tot">11</strong>건</p>
#  <div class="btn-wrap">
#  <button class="btn-list-filter pseudo-icn lazyBg blk-arw" type="button">정확도순</button>
#  <div class="layer-comn layer-filter">
#  <ul class="dev_list_filter" data-key="Ord">
#  <li><button class="filter " data-val="ExactDesc" type="button">정확도순</button></li>
#  <li><button class="filter " data-val="RegDtDesc" type="button">등록일순</button></li>
#  <li><button class="filter " data-val="EditDtDesc" type="button">최신업데이트순</button></li>
#  <li><button class="filter " data-val="ApplyCloseDtAsc" type="button">마감임박순</button></li>
#  <li><button class="filter " data-val="ReadCntDesc" type="button">조회수순</button></li>
#  <li><button class="filter " data-val="ApplicantDesc" type="button">지원자순</button></li>
#  </ul>
#  </div>
#  </div>
#  </div>
#  <div class="lists">
#  ﻿
#
#
#  <div class="lists-cnt dev_list" total-count="11">
#  <div class="list-default">
#  <ul class="clear">
#  <li class="list-post" data-gainfo='{"dimension42":"39947090", "dimension43":"솔루션·SI·CRM·ERP", "dimension44":"응용프로그래머,빅데이터·AI(인공지능)", "dimension45":"[모아소프트] AI/Data Science연구소 소프트웨어 개발인력 구인", "dimension46":"서울", "dimension65":"Y", "dimension66":"일반기업", "dimension70":"무료"}' data-gavirturl="https://www.jobkorea.co.kr/virtual/Recruit/GI_Read/39947090?Oem_Code=C1&amp;logpath=1&amp;stext=data science&amp;listno=1" data-gino="42772184" data-gno="39947090" data-listno="1" data-mem-sys="32116" data-mem-type="C">
#  <div class="post">
#  <div class="post-list-corp">
#  <a class="name dev_view" href="/Recruit/GI_Read/39947090?Oem_Code=C1&amp;logpath=1&amp;stext=data science&amp;listno=1" nav-src="/Search/_ContentsGIRead?Gno=39947090&amp;Mem_Type_Code=C&amp;Mem_Sys_No=32116" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=39947090]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=39947090]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="㈜모아소프트">㈜모아소프트</a>
#  <button class="btn-fav pseudo-icn-old lazyBg heart dev_favor-32116 " onclick="GA_Event('통합검색_PC', '채용정보','관심_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">관심기업</button>
#  </div>
#  <div class="post-list-info">
#  <a class="title dev_view" href="/Recruit/GI_Read/39947090?Oem_Code=C1&amp;logpath=1&amp;stext=data science&amp;listno=1" nav-src="/Search/_ContentsGIRead?Gno=39947090&amp;Mem_Type_Code=C&amp;Mem_Sys_No=32116" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=39947090]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=39947090]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="[모아소프트] AI/Data Science연구소 소프트웨어 개발인력 구인">
#                                  [모아소프트] AI/<strong>Data Science</strong>연구소 소프트웨어 개발인력 구인
#                              </a>
#  <p class="option">
#  <span class="exp">신입·경력</span>
#  <span class="edu">대졸↑</span>
#  <span>정규직 외</span>
#  <span class="loc short">서울</span>
#  <span class="loc long">서울 송파구</span>
#  <span class="date">상시채용</span>
#  </p>
#  <p class="etc">소프트웨어개발, 솔루션, C, C++, Java, Python</p>
#  <button class="btn-scrap pseudo-icn-old lazyBg star dev_scrap-42772184 " data-brazeinfo="[모아소프트] AI/Data Science연구소 소프트웨어 개발인력 구인|39947090|42772184|yyyy-MM-dd|yyyy-MM-dd|㈜모아소프트|32116" onclick="GA_Event('통합검색_PC', '채용정보','스크랩_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">스크랩</button>
#  </div>
#  <div class="post-list-apply">
#  <button class="btn-post-apply dev_direct_apply_list" onclick="GA_Event('통합검색_PC', '채용정보', '즉시지원');" type="button"><span>즉시지원</span></button>
#  </div>
#  </div>
#  </li>
#  <li class="list-post" data-gainfo='{"dimension42":"40092005", "dimension43":"게임·애니메이션", "dimension44":"응용프로그래머,빅데이터·AI(인공지능)", "dimension45":"[엔씨소프트]빅데이터 플랫폼 관리도구(웹) 개발자 모집", "dimension46":"경기", "dimension65":"N", "dimension66":"일반기업", "dimension70":"무료"}' data-gavirturl="https://www.jobkorea.co.kr/virtual/Recruit/GI_Read/40092005?Oem_Code=C1&amp;logpath=1&amp;stext=data science&amp;listno=2" data-gino="42903221" data-gno="40092005" data-listno="2" data-mem-sys="200528" data-mem-type="C">
#  <div class="post">
#  <div class="post-list-corp">
#  <a class="name dev_view" href="/Recruit/GI_Read/40092005?Oem_Code=C1&amp;logpath=1&amp;stext=data science&amp;listno=2" nav-src="/Search/_ContentsGIRead?Gno=40092005&amp;Mem_Type_Code=C&amp;Mem_Sys_No=200528" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=40092005]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=40092005]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="㈜엔씨소프트">㈜엔씨소프트</a>
#  <button class="btn-fav pseudo-icn-old lazyBg heart dev_favor-200528 " onclick="GA_Event('통합검색_PC', '채용정보','관심_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">관심기업</button>
#  </div>
#  <div class="post-list-info">
#  <a class="title dev_view" href="/Recruit/GI_Read/40092005?Oem_Code=C1&amp;logpath=1&amp;stext=data science&amp;listno=2" nav-src="/Search/_ContentsGIRead?Gno=40092005&amp;Mem_Type_Code=C&amp;Mem_Sys_No=200528" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=40092005]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=40092005]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="[엔씨소프트]빅데이터 플랫폼 관리도구(웹) 개발자 모집">
#                                  [엔씨소프트]빅데이터 플랫폼 관리도구(웹) 개발자 모집
#                              </a>
#  <p class="option">
#  <span class="exp">경력3년↑</span>
#  <span class="edu">학력무관</span>
#  <span>정규직</span>
#  <span class="loc short">경기</span>
#  <span class="loc long">경기 성남시</span>
#  <span class="date">~11/25(금)</span>
#  </p>
#  <p class="etc">프로그램개발, RDBMS, 3D온라인게임, 게임개발, 게임기획, 게임디자인, 게임소프트웨어, 게임시나리오, 게임운영관리, 모션그래픽, 베타테스터, 아케이드게임, 웹게임, 콘솔게임, 퍼블리싱, Java게임, RPG, Java, Linux, Python, SQL, 빅데이터, 하둡(Hadoop), Spark, Hive</p>
#  <button class="btn-scrap pseudo-icn-old lazyBg star dev_scrap-42903221 " data-brazeinfo="[엔씨소프트]빅데이터 플랫폼 관리도구(웹) 개발자 모집|40092005|42903221|yyyy-MM-dd|yyyy-MM-dd|㈜엔씨소프트|200528" onclick="GA_Event('통합검색_PC', '채용정보','스크랩_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">스크랩</button>
#  </div>
#  <div class="post-list-apply">
#  <button class="btn-post-homepage dev_new_pop" onclick="_LA.EVT('5283');GA_Event('통합검색_PC', '채용정보', '홈페이지 지원');" src="/List_GI/GIB_Read_homepage_Link.asp?GI_NO=42903221" type="button"><span>홈페이지 지원</span></button>
#  </div>
#  </div>
#  </li>
#  <li class="list-post" data-gainfo='{"dimension42":"40185837", "dimension43":"솔루션·SI·CRM·ERP", "dimension44":"응용프로그래머,DBA·데이터베이스", "dimension45":"[KSTEC] Optimization &amp; AI 기술융합 신입 컨설턴트 모집", "dimension46":"서울, 경기", "dimension65":"Y", "dimension66":"일반기업", "dimension70":"무료"}' data-gavirturl="https://www.jobkorea.co.kr/virtual/Recruit/GI_Read/40185837?Oem_Code=C1&amp;logpath=1&amp;stext=data science&amp;listno=3" data-gino="42987795" data-gno="40185837" data-listno="3" data-mem-sys="276021" data-mem-type="C">
#  <div class="post">
#  <div class="post-list-corp">
#  <a class="name dev_view" href="/Recruit/GI_Read/40185837?Oem_Code=C1&amp;logpath=1&amp;stext=data science&amp;listno=3" nav-src="/Search/_ContentsGIRead?Gno=40185837&amp;Mem_Type_Code=C&amp;Mem_Sys_No=276021" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=40185837]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=40185837]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="지식시스템㈜ KSTEC">지식시스템㈜ KSTEC</a>
#  <button class="btn-fav pseudo-icn-old lazyBg heart dev_favor-276021 " onclick="GA_Event('통합검색_PC', '채용정보','관심_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">관심기업</button>
#  </div>
#  <div class="post-list-info">
#  <a class="title dev_view" href="/Recruit/GI_Read/40185837?Oem_Code=C1&amp;logpath=1&amp;stext=data science&amp;listno=3" nav-src="/Search/_ContentsGIRead?Gno=40185837&amp;Mem_Type_Code=C&amp;Mem_Sys_No=276021" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=40185837]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=40185837]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="[KSTEC] Optimization &amp; AI 기술융합 신입 컨설턴트 모집">
#                                  [KSTEC] Optimization &amp; AI 기술융합 신입 컨설턴트 모집
#                              </a>
#  <p class="option">
#  <span class="exp">신입</span>
#  <span class="edu">대졸↑</span>
#  <span>정규직</span>
#  <span class="loc short">경기 외</span>
#  <span class="loc long">경기 성남시 외</span>
#  <span class="date">~11/30(수)</span>
#  </p>
#  <p class="etc">ERP, SCM, 시스템분석설계, APS, DB, 소프트웨어개발, 솔루션, 데이터베이스, DBA, 응용프로그래머, C++, Python</p>
#  <button class="btn-scrap pseudo-icn-old lazyBg star dev_scrap-42987795 " data-brazeinfo="[KSTEC] Optimization &amp; AI 기술융합 신입 컨설턴트 모집|40185837|42987795|yyyy-MM-dd|yyyy-MM-dd|지식시스템㈜ KSTEC|276021" onclick="GA_Event('통합검색_PC', '채용정보','스크랩_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">스크랩</button>
#  </div>
#  <div class="post-list-apply">
#  <button class="btn-post-apply dev_direct_apply_list" onclick="GA_Event('통합검색_PC', '채용정보', '즉시지원');" type="button"><span>즉시지원</span></button>
#  </div>
#  </div>
#  </li>
#  <li class="list-post" data-gainfo='{"dimension42":"40185820", "dimension43":"솔루션·SI·CRM·ERP", "dimension44":"응용프로그래머,DBA·데이터베이스", "dimension45":"[KSTEC] Prescriptive Analytics 컨설턴트 신입 채용", "dimension46":"서울, 경기", "dimension65":"Y", "dimension66":"일반기업", "dimension70":"무료"}' data-gavirturl="https://www.jobkorea.co.kr/virtual/Recruit/GI_Read/40185820?Oem_Code=C1&amp;logpath=1&amp;stext=data science&amp;listno=4" data-gino="42987780" data-gno="40185820" data-listno="4" data-mem-sys="276021" data-mem-type="C">
#  <div class="post">
#  <div class="post-list-corp">
#  <a class="name dev_view" href="/Recruit/GI_Read/40185820?Oem_Code=C1&amp;logpath=1&amp;stext=data science&amp;listno=4" nav-src="/Search/_ContentsGIRead?Gno=40185820&amp;Mem_Type_Code=C&amp;Mem_Sys_No=276021" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=40185820]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=40185820]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="지식시스템㈜ KSTEC">지식시스템㈜ KSTEC</a>
#  <button class="btn-fav pseudo-icn-old lazyBg heart dev_favor-276021 " onclick="GA_Event('통합검색_PC', '채용정보','관심_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">관심기업</button>
#  </div>
#  <div class="post-list-info">
#  <a class="title dev_view" href="/Recruit/GI_Read/40185820?Oem_Code=C1&amp;logpath=1&amp;stext=data science&amp;listno=4" nav-src="/Search/_ContentsGIRead?Gno=40185820&amp;Mem_Type_Code=C&amp;Mem_Sys_No=276021" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=40185820]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=40185820]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="[KSTEC] Prescriptive Analytics 컨설턴트 신입 채용">
#                                  [KSTEC] Prescriptive Analytics 컨설턴트 신입 채용
#                              </a>
#  <p class="option">
#  <span class="exp">신입</span>
#  <span class="edu">대졸↑</span>
#  <span>정규직 외</span>
#  <span class="loc short">경기 외</span>
#  <span class="loc long">경기 성남시 외</span>
#  <span class="date">~11/30(수)</span>
#  </p>
#  <p class="etc">ERP, SCM, 시스템분석설계, APS, DB, 데이터베이스, DBA, 응용프로그래머, C++, Python</p>
#  <button class="btn-scrap pseudo-icn-old lazyBg star dev_scrap-42987780 " data-brazeinfo="[KSTEC] Prescriptive Analytics 컨설턴트 신입 채용|40185820|42987780|yyyy-MM-dd|yyyy-MM-dd|지식시스템㈜ KSTEC|276021" onclick="GA_Event('통합검색_PC', '채용정보','스크랩_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">스크랩</button>
#  </div>
#  <div class="post-list-apply">
#  <button class="btn-post-apply dev_direct_apply_list" onclick="GA_Event('통합검색_PC', '채용정보', '즉시지원');" type="button"><span>즉시지원</span></button>
#  </div>
#  </div>
#  </li>
#  <li class="list-post" data-gainfo='{"dimension42":"40070684", "dimension43":"전기·전자·제어", "dimension44":"응용프로그래머,빅데이터·AI(인공지능),소프트웨어·하드웨어", "dimension45":"인공지능(AI), 데이터 사이언스 (알고리즘 개발) 팀원 모집", "dimension46":"서울", "dimension65":"Y", "dimension66":"일반기업", "dimension70":"무료"}' data-gavirturl="https://www.jobkorea.co.kr/virtual/Recruit/GI_Read/40070684?Oem_Code=C1&amp;logpath=1&amp;stext=data science&amp;listno=5" data-gino="42883755" data-gno="40070684" data-listno="5" data-mem-sys="31536170" data-mem-type="C">
#  <div class="post">
#  <div class="post-list-corp">
#  <a class="name dev_view" href="/Recruit/GI_Read/40070684?Oem_Code=C1&amp;logpath=1&amp;stext=data science&amp;listno=5" nav-src="/Search/_ContentsGIRead?Gno=40070684&amp;Mem_Type_Code=C&amp;Mem_Sys_No=31536170" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=40070684]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=40070684]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="에타일렉트로닉스">에타일렉트로닉스</a>
#  <button class="btn-fav pseudo-icn-old lazyBg heart dev_favor-31536170 " onclick="GA_Event('통합검색_PC', '채용정보','관심_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">관심기업</button>
#  </div>
#  <div class="post-list-info">
#  <a class="title dev_view" href="/Recruit/GI_Read/40070684?Oem_Code=C1&amp;logpath=1&amp;stext=data science&amp;listno=5" nav-src="/Search/_ContentsGIRead?Gno=40070684&amp;Mem_Type_Code=C&amp;Mem_Sys_No=31536170" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=40070684]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=40070684]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="인공지능(AI), 데이터 사이언스 (알고리즘 개발) 팀원 모집">
#                                  인공지능(AI), 데이터 사이언스 (알고리즘 개발) 팀원 모집
#                              </a>
#  <p class="option">
#  <span class="exp">경력무관</span>
#  <span class="edu">대졸↑</span>
#  <span>정규직</span>
#  <span class="loc short">서울</span>
#  <span class="loc long">서울 용산구</span>
#  <span class="date">상시채용</span>
#  </p>
#  <p class="etc">전자회로, Firmware, Hardware, PCB, SMPS, Python, 인공지능(AI), 빅데이터, 머신러닝(ML), 딥러닝, 데이터분석, 소프트웨어</p>
#  <button class="btn-scrap pseudo-icn-old lazyBg star dev_scrap-42883755 " data-brazeinfo="인공지능(AI), 데이터 사이언스 (알고리즘 개발) 팀원 모집|40070684|42883755|yyyy-MM-dd|yyyy-MM-dd|에타일렉트로닉스|31536170" onclick="GA_Event('통합검색_PC', '채용정보','스크랩_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">스크랩</button>
#  </div>
#  <div class="post-list-apply">
#  <button class="btn-post-apply dev_direct_apply_list" onclick="GA_Event('통합검색_PC', '채용정보', '즉시지원');" type="button"><span>즉시지원</span></button>
#  </div>
#  </div>
#  </li>
#  <li class="list-post" data-gainfo='{"dimension42":"40055690", "dimension43":"제약·보건·바이오", "dimension44":"기획·전략·경영,마케팅·광고·분석,제품·서비스영업,웹프로그래머,응용프로그래머,화학·에너지·환경,바이오·제약·식품", "dimension45":"(주)넷타겟 각 부문별 수시채용", "dimension46":"경기, 대전", "dimension65":"Y", "dimension66":"일반기업", "dimension70":"무료"}' data-gavirturl="https://www.jobkorea.co.kr/virtual/Recruit/GI_Read/40055690?Oem_Code=C1&amp;logpath=1&amp;stext=data science&amp;listno=6" data-gino="42870049" data-gno="40055690" data-listno="6" data-mem-sys="30940370" data-mem-type="C">
#  <div class="post">
#  <div class="post-list-corp">
#  <a class="name dev_view" href="/Recruit/GI_Read/40055690?Oem_Code=C1&amp;logpath=1&amp;stext=data science&amp;listno=6" nav-src="/Search/_ContentsGIRead?Gno=40055690&amp;Mem_Type_Code=C&amp;Mem_Sys_No=30940370" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=40055690]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=40055690]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="㈜넷타겟">㈜넷타겟</a>
#  <button class="btn-fav pseudo-icn-old lazyBg heart dev_favor-30940370 " onclick="GA_Event('통합검색_PC', '채용정보','관심_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">관심기업</button>
#  </div>
#  <div class="post-list-info">
#  <a class="title dev_view" href="/Recruit/GI_Read/40055690?Oem_Code=C1&amp;logpath=1&amp;stext=data science&amp;listno=6" nav-src="/Search/_ContentsGIRead?Gno=40055690&amp;Mem_Type_Code=C&amp;Mem_Sys_No=30940370" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=40055690]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=40055690]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="(주)넷타겟 각 부문별 수시채용">
#                                  (주)넷타겟 각 부문별 수시채용
#                              </a>
#  <p class="option">
#  <span class="exp">경력무관</span>
#  <span class="edu">대졸↑</span>
#  <span>정규직</span>
#  <span class="loc short">대전 외</span>
#  <span class="loc long">대전 유성구 외</span>
#  <span class="date">상시채용</span>
#  </p>
#  <p class="etc">바이오, 기획, 전략, 마케팅, 마케팅기획, 바이럴마케팅, 국내영업, 해외영업, 웹프로그래머, Python, API, Python, 연구관리, 연구원, R&amp;D, 바이오, 제약, 의약품</p>
#  <button class="btn-scrap pseudo-icn-old lazyBg star dev_scrap-42870049 " data-brazeinfo="(주)넷타겟 각 부문별 수시채용|40055690|42870049|yyyy-MM-dd|yyyy-MM-dd|㈜넷타겟|30940370" onclick="GA_Event('통합검색_PC', '채용정보','스크랩_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">스크랩</button>
#  </div>
#  <div class="post-list-apply">
#  <button class="btn-post-apply dev_direct_apply_list" onclick="GA_Event('통합검색_PC', '채용정보', '즉시지원');" type="button"><span>즉시지원</span></button>
#  </div>
#  </div>
#  </li>
#  <li class="list-post" data-gainfo='{"dimension42":"39672580", "dimension43":"학원·어학원·교육원", "dimension44":"응용프로그래머,컨텐츠·사이트운영,IT·디자인·컴퓨터강사", "dimension45":"[경력/정규직] 코딩 콘텐츠 기획 및 개발자 모집", "dimension46":"서울", "dimension65":"Y", "dimension66":"일반기업", "dimension70":"무료"}' data-gavirturl="https://www.jobkorea.co.kr/virtual/Recruit/GI_Read/39672580?Oem_Code=C1&amp;logpath=1&amp;stext=data science&amp;listno=7" data-gino="42524745" data-gno="39672580" data-listno="7" data-mem-sys="33432" data-mem-type="C">
#  <div class="post">
#  <div class="post-list-corp">
#  <a class="name dev_view" href="/Recruit/GI_Read/39672580?Oem_Code=C1&amp;logpath=1&amp;stext=data science&amp;listno=7" nav-src="/Search/_ContentsGIRead?Gno=39672580&amp;Mem_Type_Code=C&amp;Mem_Sys_No=33432" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=39672580]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=39672580]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="㈜크레버스(Creverse, Inc.)">㈜크레버스(Creverse, Inc.)</a>
#  <button class="btn-fav pseudo-icn-old lazyBg heart dev_favor-33432 " onclick="GA_Event('통합검색_PC', '채용정보','관심_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">관심기업</button>
#  </div>
#  <div class="post-list-info">
#  <a class="title dev_view" href="/Recruit/GI_Read/39672580?Oem_Code=C1&amp;logpath=1&amp;stext=data science&amp;listno=7" nav-src="/Search/_ContentsGIRead?Gno=39672580&amp;Mem_Type_Code=C&amp;Mem_Sys_No=33432" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=39672580]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=39672580]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="[경력/정규직] 코딩 콘텐츠 기획 및 개발자 모집">
#                                  [경력/정규직] 코딩 콘텐츠 기획 및 개발자 모집
#                              </a>
#  <p class="option">
#  <span class="exp">경력3년↑</span>
#  <span class="edu">대졸↑</span>
#  <span>정규직</span>
#  <span class="loc short">서울</span>
#  <span class="loc long">서울 강남구</span>
#  <span class="date">상시채용</span>
#  </p>
#  <p class="etc">어학원, 컨텐츠개발, C, Java, Python, 컨텐츠개발, 프로그램강의</p>
#  <button class="btn-scrap pseudo-icn-old lazyBg star dev_scrap-42524745 " data-brazeinfo="[경력/정규직] 코딩 콘텐츠 기획 및 개발자 모집|39672580|42524745|yyyy-MM-dd|yyyy-MM-dd|㈜크레버스(Creverse, Inc.)|33432" onclick="GA_Event('통합검색_PC', '채용정보','스크랩_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">스크랩</button>
#  </div>
#  <div class="post-list-apply">
#  <button class="btn-post-apply dev_direct_apply_list" onclick="GA_Event('통합검색_PC', '채용정보', '즉시지원');" type="button"><span>즉시지원</span></button>
#  </div>
#  </div>
#  </li>
#  <li class="list-post" data-gainfo='{"dimension42":"39584238", "dimension43":"솔루션·SI·CRM·ERP", "dimension44":"응용프로그래머,빅데이터·AI(인공지능),소프트웨어·하드웨어", "dimension45":"Recruitment Analytical Consultant (SAS)", "dimension46":"서울", "dimension65":"Y", "dimension66":"일반기업", "dimension70":"무료"}' data-gavirturl="https://www.jobkorea.co.kr/virtual/Recruit/GI_Read/39584238?Oem_Code=C1&amp;logpath=1&amp;stext=data science&amp;listno=8" data-gino="42445586" data-gno="39584238" data-listno="8" data-mem-sys="37316540" data-mem-type="C">
#  <div class="post">
#  <div class="post-list-corp">
#  <a class="name dev_view" href="/Recruit/GI_Read/39584238?Oem_Code=C1&amp;logpath=1&amp;stext=data science&amp;listno=8" nav-src="/Search/_ContentsGIRead?Gno=39584238&amp;Mem_Type_Code=C&amp;Mem_Sys_No=37316540" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=39584238]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=39584238]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="SAS Software Korea Ltd Co">SAS Software Korea Ltd Co</a>
#  <button class="btn-fav pseudo-icn-old lazyBg heart dev_favor-37316540 " onclick="GA_Event('통합검색_PC', '채용정보','관심_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">관심기업</button>
#  </div>
#  <div class="post-list-info">
#  <a class="title dev_view" href="/Recruit/GI_Read/39584238?Oem_Code=C1&amp;logpath=1&amp;stext=data science&amp;listno=8" nav-src="/Search/_ContentsGIRead?Gno=39584238&amp;Mem_Type_Code=C&amp;Mem_Sys_No=37316540" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=39584238]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=39584238]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="Recruitment Analytical Consultant (SAS)">
#                                  Recruitment Analytical Consultant (SAS)
#                              </a>
#  <p class="option">
#  <span class="exp">경력3년↑</span>
#  <span class="edu">초대졸↑</span>
#  <span>정규직</span>
#  <span class="loc short">서울</span>
#  <span class="loc long">서울 서초구</span>
#  <span class="date">상시채용</span>
#  </p>
#  <p class="etc">SAS, 솔루션, BI, BigData, DataMining, DW, Python, SQL, Python, 머신러닝(ML), R, 소프트웨어</p>
#  <button class="btn-scrap pseudo-icn-old lazyBg star dev_scrap-42445586 " data-brazeinfo="Recruitment Analytical Consultant (SAS)|39584238|42445586|yyyy-MM-dd|yyyy-MM-dd|SAS Software Korea Ltd Co|37316540" onclick="GA_Event('통합검색_PC', '채용정보','스크랩_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">스크랩</button>
#  </div>
#  <div class="post-list-apply">
#  <button class="btn-post-apply dev_direct_apply_list" onclick="GA_Event('통합검색_PC', '채용정보', '즉시지원');" type="button"><span>즉시지원</span></button>
#  </div>
#  </div>
#  </li>
#  <li class="list-post" data-gainfo='{"dimension42":"39371780", "dimension43":"솔루션·SI·CRM·ERP", "dimension44":"응용프로그래머", "dimension45":"[신입/경력] python을 활용한 Ai개발 및 프론트 백앤드개발자 모집", "dimension46":"서울", "dimension65":"Y", "dimension66":"일반기업", "dimension70":"무료"}' data-gavirturl="https://www.jobkorea.co.kr/virtual/Recruit/GI_Read/39371780?Oem_Code=C1&amp;logpath=1&amp;stext=data science&amp;listno=9" data-gino="42253887" data-gno="39371780" data-listno="9" data-mem-sys="34609618" data-mem-type="C">
#  <div class="post">
#  <div class="post-list-corp">
#  <a class="name dev_view" href="/Recruit/GI_Read/39371780?Oem_Code=C1&amp;logpath=1&amp;stext=data science&amp;listno=9" nav-src="/Search/_ContentsGIRead?Gno=39371780&amp;Mem_Type_Code=C&amp;Mem_Sys_No=34609618" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=39371780]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=39371780]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="㈜폼즈">㈜폼즈</a>
#  <button class="btn-fav pseudo-icn-old lazyBg heart dev_favor-34609618 " onclick="GA_Event('통합검색_PC', '채용정보','관심_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">관심기업</button>
#  </div>
#  <div class="post-list-info">
#  <a class="title dev_view" href="/Recruit/GI_Read/39371780?Oem_Code=C1&amp;logpath=1&amp;stext=data science&amp;listno=9" nav-src="/Search/_ContentsGIRead?Gno=39371780&amp;Mem_Type_Code=C&amp;Mem_Sys_No=34609618" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=39371780]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=39371780]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="[신입/경력] python을 활용한 Ai개발 및 프론트 백앤드개발자 모집">
#                                  [신입/경력] python을 활용한 Ai개발 및 프론트 백앤드개발자 모집
#                              </a>
#  <p class="option">
#  <span class="exp">경력무관</span>
#  <span class="edu">학력무관</span>
#  <span>정규직 외</span>
#  <span class="loc short">서울</span>
#  <span class="loc long">서울 구로구 외</span>
#  <span class="date">상시채용</span>
#  </p>
#  <p class="etc">소프트웨어개발, Python</p>
#  <button class="btn-scrap pseudo-icn-old lazyBg star dev_scrap-42253887 " data-brazeinfo="[신입/경력] python을 활용한 Ai개발 및 프론트 백앤드개발자 모집|39371780|42253887|yyyy-MM-dd|yyyy-MM-dd|㈜폼즈|34609618" onclick="GA_Event('통합검색_PC', '채용정보','스크랩_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">스크랩</button>
#  </div>
#  <div class="post-list-apply">
#  <button class="btn-post-apply dev_direct_apply_list" onclick="GA_Event('통합검색_PC', '채용정보', '즉시지원');" type="button"><span>즉시지원</span></button>
#  </div>
#  </div>
#  </li>
#  <li class="list-post" data-gainfo='{"dimension42":"40213432", "dimension43":"제약·보건·바이오", "dimension44":"기획·전략·경영,사무·총무·법무,인사·노무·교육,재무·세무·IR,마케팅·광고·분석,홍보·PR,해외영업·무역영업,구매·자재,웹프로그래머,응용프로그래머,웹기획·PM,ERP·시스템분석·설계,생산관리·공정관리·품질관리,바이오·제약·식품", "dimension45":"지니너스㈜ 신입 및 경력 수시채용", "dimension46":"서울", "dimension65":"Y", "dimension66":"일반기업", "dimension70":"무료"}' data-gavirturl="https://www.jobkorea.co.kr/virtual/Recruit/GI_Read/40213432?Oem_Code=C1&amp;logpath=1&amp;stext=data science&amp;listno=10" data-gino="43012312" data-gno="40213432" data-listno="10" data-mem-sys="27127417" data-mem-type="C">
#  <div class="post">
#  <div class="post-list-corp">
#  <a class="name dev_view" href="/Recruit/GI_Read/40213432?Oem_Code=C1&amp;logpath=1&amp;stext=data science&amp;listno=10" nav-src="/Search/_ContentsGIRead?Gno=40213432&amp;Mem_Type_Code=C&amp;Mem_Sys_No=27127417" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=40213432]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=40213432]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="지니너스㈜">지니너스㈜</a>
#  <button class="btn-fav pseudo-icn-old lazyBg heart dev_favor-27127417 " onclick="GA_Event('통합검색_PC', '채용정보','관심_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">관심기업</button>
#  </div>
#  <div class="post-list-info">
#  <a class="title dev_view" href="/Recruit/GI_Read/40213432?Oem_Code=C1&amp;logpath=1&amp;stext=data science&amp;listno=10" nav-src="/Search/_ContentsGIRead?Gno=40213432&amp;Mem_Type_Code=C&amp;Mem_Sys_No=27127417" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=40213432]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=40213432]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="지니너스㈜ 신입 및 경력 수시채용">
#                                  지니너스㈜ 신입 및 경력 수시채용
#                              </a>
#  <p class="option">
#  <span class="exp">신입·경력</span>
#  <span class="edu">학력무관</span>
#  <span>정규직 외</span>
#  <span class="loc short">서울</span>
#  <span class="loc long">서울 송파구</span>
#  <span class="date">~02/06(월)</span>
#  </p>
#  <p class="etc">세포 배양, DNA, GMP, NGS, RNA Prep, 면역 세포 분리, 단일세포 전사체 분석, NGS 데이터, 유전체 데이터 생산, 조직생검 유래 암 유전체 데이터 분석, 바이오, 생명공학, 경영기획, 기획, 기획조사, 사업기획, 전략, 관리, 문서관리, 사무행정, 인사, 인사기획, 인사통합, HRD, HRM, 공시, 자금, 재무기획, 재무회계, 주식IR, 마케팅, 마케팅기획, 브랜딩, 소셜미디어, 시장분석, 홍보, SNS운영, 영어, 해외마케팅, 해외영업, 구매관리, 자재구매기획, 재고관리, API, Java, Python, 시스템분석, 시스템엔지니어, 생산관리, 품질관리, 바이오, 의료, 세포배양, 유전공학</p>
#  <button class="btn-scrap pseudo-icn-old lazyBg star dev_scrap-43012312 " data-brazeinfo="지니너스㈜ 신입 및 경력 수시채용|40213432|43012312|yyyy-MM-dd|yyyy-MM-dd|지니너스㈜|27127417" onclick="GA_Event('통합검색_PC', '채용정보','스크랩_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">스크랩</button>
#  </div>
#  <div class="post-list-apply">
#  <button class="btn-post-apply dev_direct_apply_list" onclick="GA_Event('통합검색_PC', '채용정보', '즉시지원');" type="button"><span>즉시지원</span></button>
#  </div>
#  </div>
#  </li>
#  <li class="list-post" data-gainfo='{"dimension42":"39911204", "dimension43":"제약·보건·바이오", "dimension44":"기획·전략·경영,사무·총무·법무,인사·노무·교육,재무·세무·IR,마케팅·광고·분석,홍보·PR,해외영업·무역영업,구매·자재,웹프로그래머,응용프로그래머,웹기획·PM,웹마케팅,ERP·시스템분석·설계,빅데이터·AI(인공지능),생산관리·공정관리·품질관리,화학·에너지·환경,통신기술·네트워크구축,바이오·제약·식품,의사·치과·한의사,약사·한약사·약무보조,간호사,의료직기타", "dimension45":"지니너스㈜ 신입/경력 수시채용", "dimension46":"서울", "dimension65":"Y", "dimension66":"일반기업", "dimension70":"무료"}' data-gavirturl="https://www.jobkorea.co.kr/virtual/Recruit/GI_Read/39911204?Oem_Code=C1&amp;logpath=1&amp;stext=data science&amp;listno=11" data-gino="42740242" data-gno="39911204" data-listno="11" data-mem-sys="27127417" data-mem-type="C">
#  <div class="post">
#  <div class="post-list-corp">
#  <a class="name dev_view" href="/Recruit/GI_Read/39911204?Oem_Code=C1&amp;logpath=1&amp;stext=data science&amp;listno=11" nav-src="/Search/_ContentsGIRead?Gno=39911204&amp;Mem_Type_Code=C&amp;Mem_Sys_No=27127417" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=39911204]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=39911204]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="지니너스㈜">지니너스㈜</a>
#  <button class="btn-fav pseudo-icn-old lazyBg heart dev_favor-27127417 " onclick="GA_Event('통합검색_PC', '채용정보','관심_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">관심기업</button>
#  </div>
#  <div class="post-list-info">
#  <a class="title dev_view" href="/Recruit/GI_Read/39911204?Oem_Code=C1&amp;logpath=1&amp;stext=data science&amp;listno=11" nav-src="/Search/_ContentsGIRead?Gno=39911204&amp;Mem_Type_Code=C&amp;Mem_Sys_No=27127417" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=39911204]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=39911204]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="지니너스㈜ 신입/경력 수시채용">
#                                  지니너스㈜ 신입/경력 수시채용
#                              </a>
#  <p class="option">
#  <span class="exp">신입·경력</span>
#  <span class="edu">학력무관</span>
#  <span>정규직 외</span>
#  <span class="loc short">서울</span>
#  <span class="loc long">서울 송파구</span>
#  <span class="date today">~11/11(금)</span>
#  </p>
#  <p class="etc">R, 세포 배양, 클라우드 컴퓨팅, AI, DNA, FACS, ELISA, EMR, Docker, GMP, ISO13485, KGMP, json, Microarray, ML, NGS, MVC, QC, QMS, SCI, Shell Script, Trobleshooting, RNA Prep, 전사체, Cell-free DNA, 면역 세포 분리, SCIE, 단일세포 전사체 분석, NGS 데이터, 유전체 데이터 생산, ELISpot, FACS 분석, 면역 세포 배양, mRNA transfection, 임상검체 DNA, DTC 유전자검사 마케팅, 조직생검 유래 암 유전체 데이터 분석, IVDR, 바이오, 생명공학, 경영기획, 기획, 기획조사, 사업기획, 사업제휴, 서비스기획, 신규사업·BD, 전략, 조직관리, 타당성분석, 관리, 문서관리, 사무행정, 교육, 인사, 채용·면접, HRD, 자금, 주식IR, 마케팅, 마케팅기획, 브랜딩, 소셜미디어, 시장분석, 홍보, SNS운영, 영어, 해외마케팅, 해외영업, 구매관리, 자재구매기획, 재고관리, 웹기획, 온라인마케팅, 웹마케팅, 웹프로그래머, Java, MySQL, Python, API, Java, Python, 시스템분석, 시스템엔지니어, Python, 생산관리, 품질관리, 기술연구소, 생명공학, 실험, 연구원, R&amp;D, 바이오, 세포배양, 유전공학</p>
#  <button class="btn-scrap pseudo-icn-old lazyBg star dev_scrap-42740242 " data-brazeinfo="지니너스㈜ 신입/경력 수시채용|39911204|42740242|yyyy-MM-dd|yyyy-MM-dd|지니너스㈜|27127417" onclick="GA_Event('통합검색_PC', '채용정보','스크랩_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">스크랩</button>
#  </div>
#  <div class="post-list-apply">
#  <button class="btn-post-apply dev_direct_apply_list" onclick="GA_Event('통합검색_PC', '채용정보', '즉시지원');" type="button"><span>즉시지원</span></button>
#  </div>
#  </div>
#  </li>
#  </ul>
#  </div>
#  <div class="list-famous">
#  <p class="tit"><em>인기공고</em></p>
#  <ul class="clear">
#  <li class="list-post" data-gainfo='{"dimension42":"40186364", "dimension43":"기계·기계설비", "dimension44":"기획·전략·경영,경리·회계·결산,재무·세무·IR,사무보조·문서작성,마케팅·광고·분석,해외영업·무역영업,유통·물류·재고,영업관리·지원·영업기획,응용프로그래머,시스템프로그래머,컨텐츠·사이트운영,소프트웨어·하드웨어,생산관리·공정관리·품질관리,생산·제조·설비·조립,포장·가공,자동차·조선·기계,반도체·디스플레이,전기·전자·제어,기계설계·CAD·CAM,설치·정비·A/S,연구소·R&amp;D", "dimension45":"2023년 1분기 캐논코리아 정기신입사원(채용연계형인턴) 모집", "dimension46":"서울, 경기", "dimension65":"N", "dimension66":"일반기업", "dimension70":"유료"}' data-gavirturl="https://www.jobkorea.co.kr/virtual/Recruit/GI_Read/40186364?Oem_Code=C1&amp;logpath=1" data-gino="42988219" data-gno="40186364" data-mem-sys="227977" data-mem-type="C">
#  <div class="post">
#  <div class="post-list-corp">
#  <a class="name dev_view" href="/Recruit/GI_Read/40186364?Oem_Code=C1&amp;logpath=1" nav-src="/Search/_ContentsGIRead?Gno=40186364&amp;Mem_Type_Code=C&amp;Mem_Sys_No=227977" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=40186364]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=40186364]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');">캐논코리아 주식회사 </a>
#  <button class="btn-fav pseudo-icn-old lazyBg heart dev_favor-227977 " onclick="GA_Event('통합검색_PC', '채용정보','관심_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">관심기업</button>
#  </div>
#  <div class="post-list-info">
#  <a class="title dev_view" href="/Recruit/GI_Read/40186364?Oem_Code=C1&amp;logpath=1" nav-src="/Search/_ContentsGIRead?Gno=40186364&amp;Mem_Type_Code=C&amp;Mem_Sys_No=227977" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=40186364]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=40186364]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');">2023년 1분기 캐논코리아 정기신입사원(채용연계형인턴) 모집</a>
#  <p class="option">
#  <span>신입</span>
#  <span class="edu">대졸↑</span>
#  <span>인턴</span>
#  <span class="loc short">경기 외</span>
#  <span class="loc long">경기 안산시 외</span>
#  <span class="date">~11/20(일)</span>
#  </p>
#  <p class="etc">기계, 경영기획, 기획, 기획조사, 전략, 홈페이지관리, 결산, 원가, 원가회계, 회계, 회계감사, 감사, 결산, 재무, 재무기획, 재무회계, 라이센싱, 마케팅, 시장분석, 업무제휴, 판촉, 퍼블리싱, 물류, 일본어, 거래선개발관리, 거래처관리, 고객관리, 매출관리, 영업관리, 영업기획, 영업지원, Embedded, 임베디드, HMI, PLC, 컨텐츠관리, 유지보수, 하드웨어, 소프트웨어, 공정, 공정관리, 생산, 생산관리, 원가관리, 설비, 조립, 포장, 금형설계, 기계, 기구설계, 기술연구소, 기술직, 생산기술, 연구관리, 연구원, 제어, 제품개발, 기구설계, 기술연구소, 디스플레이, 메카트로닉스, 생산기술, 연구원, 전기·전자, 제어, 제품개발, R&amp;D, 공정엔지니어, 설계엔지니어, 유지보수, 임베디드, 전기, 전기·전자회로, 전기설비, 품질엔지니어, 하드웨어, PLC, 3D설계, 금형설계, 기계설계, 기구설계, 전기설계, AutoCad, CAD, 설치, 전기·전자, 연구·실험·기술, 제조·공정</p>
#  <button class="btn-scrap pseudo-icn-old lazyBg star dev_scrap-42988219 " data-brazeinfo="2023년 1분기 캐논코리아 정기신입사원(채용연계형인턴) 모집|40186364|42988219|2022-11-07|2022-11-20|캐논코리아 주식회사 |227977" onclick="GA_Event('통합검색_PC', '채용정보','스크랩_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">스크랩</button>
#  </div>
#  <div class="post-list-apply">
#  <button class="btn-post-homepage dev_new_pop" onclick="_LA.EVT('5283');GA_Event('통합검색_PC', '채용정보', '홈페이지 지원');" src="/Recruit/GIReadHomepageLink?GI_NO=42988219" type="button"><span>홈페이지 지원</span></button>
#  </div>
#  </div>
#  </li>
#  <li class="list-post" data-gainfo='{"dimension42":"39730993", "dimension43":"솔루션·SI·CRM·ERP,쇼핑몰·오픈마켓·소셜커머스,정보보안,모바일·APP,IT컨설팅", "dimension44":"기획·전략·경영,경리·회계·결산,재무·세무·IR,사무보조·문서작성,구매·자재,상품기획·MD,제품·서비스영업,IT·솔루션·기술영업,영업관리·지원·영업기획,법인영업,판매·서빙·매장관리,웹프로그래머,응용프로그래머,시스템프로그래머,DBA·데이터베이스,네트워크·서버·보안,웹기획·PM,컨텐츠·사이트운영,HTML·퍼블리싱·UI개발,QA·테스터·검증,ERP·시스템분석·설계,빅데이터·AI(인공지능),소프트웨어·하드웨어", "dimension45":"신세계아이앤씨 SW개발/운영, 기획, 클라우드, AI, 영업, 보안 경력직 모집", "dimension46":"서울, 경기", "dimension65":"N", "dimension66":"일반기업", "dimension70":"유료"}' data-gavirturl="https://www.jobkorea.co.kr/virtual/Recruit/GI_Read/39730993?Oem_Code=C1&amp;logpath=1" data-gino="42577352" data-gno="39730993" data-mem-sys="99521" data-mem-type="C">
#  <div class="post">
#  <div class="post-list-corp">
#  <a class="name dev_view" href="/Recruit/GI_Read/39730993?Oem_Code=C1&amp;logpath=1" nav-src="/Search/_ContentsGIRead?Gno=39730993&amp;Mem_Type_Code=C&amp;Mem_Sys_No=99521" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=39730993]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=39730993]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');">㈜신세계아이앤씨</a>
#  <button class="btn-fav pseudo-icn-old lazyBg heart dev_favor-99521 " onclick="GA_Event('통합검색_PC', '채용정보','관심_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">관심기업</button>
#  </div>
#  <div class="post-list-info">
#  <a class="title dev_view" href="/Recruit/GI_Read/39730993?Oem_Code=C1&amp;logpath=1" nav-src="/Search/_ContentsGIRead?Gno=39730993&amp;Mem_Type_Code=C&amp;Mem_Sys_No=99521" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=39730993]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=39730993]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');">신세계아이앤씨 SW개발/운영, 기획, 클라우드, AI, 영업, 보안 경력직 모집</a>
#  <p class="option">
#  <span>경력</span>
#  <span class="edu">학력무관</span>
#  <span>정규직</span>
#  <span class="loc short">서울 외</span>
#  <span class="loc long">서울 중구 외</span>
#  <span class="date">상시채용</span>
#  </p>
#  <p class="etc">모바일앱개발, 소프트웨어개발, 솔루션, asp, BigData, CRM, SI, WAS, 네트워크보안, 모바일App, 아이폰, 안드로이드, 사업기획, 서비스기획, 전략, 문서관리, 관리회계, 원가회계, 전산회계, 회계, 재무, 재무기획, 재무회계, AICPA, CPA, 구매관리, 유통관리, 자재관리, 유통관리, 기술영업, 솔루션영업, 매출관리, 영업관리, 기술영업, 납품영업, 리눅스, 웹마스터, 유닉스, 데이터베이스, MS-SQL, MySQL, Oracle, 데이터마이닝, 네트워크관리, 네트워크엔지니어, 방화벽, 보안관리, 보안관제, 보안기술, 서버관리자, 서버구축, 시스템운영, Apache, Linux, Unix, 모바일기획, 웹기획, 웹서비스기획, 정보설계, 컨텐츠기획, PM, UI설계, .NET, 웹프로그래머, ASP.NET, Java, jsp, MySQL, SQL, .NET, 응용프로그래머, API, Application, C, C++, Java, Linux, Oracle, Python, Unix, Windows, 시스템프로그래머, 임베디드, PLC, 컨텐츠개발, 웹퍼블리셔, UI·UX, 시스템분석, 시스템설계, 시스템엔지니어, DBA, PM, Python, 인공지능(AI), 빅데이터, 사물인터넷(IoT), 머신러닝(ML), 딥러닝, R, 데이터분석</p>
#  <button class="btn-scrap pseudo-icn-old lazyBg star dev_scrap-42577352 " data-brazeinfo="신세계아이앤씨 SW개발/운영, 기획, 클라우드, AI, 영업, 보안 경력직 모집|39730993|42577352|2022-09-21|2070-01-01|㈜신세계아이앤씨|99521" onclick="GA_Event('통합검색_PC', '채용정보','스크랩_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">스크랩</button>
#  </div>
#  <div class="post-list-apply">
#  <button class="btn-post-homepage dev_new_pop" onclick="_LA.EVT('5283');GA_Event('통합검색_PC', '채용정보', '홈페이지 지원');" src="/Recruit/GIReadHomepageLink?GI_NO=42577352" type="button"><span>홈페이지 지원</span></button>
#  </div>
#  </div>
#  </li>
#  <li class="list-post" data-gainfo='{"dimension42":"39813773", "dimension43":"음식료·외식·프랜차이즈", "dimension44":"기획·전략·경영,사무·총무·법무,인사·노무·교육,경리·회계·결산,재무·세무·IR,해외영업·무역영업,수출입·무역사무,구매·자재,상품기획·MD,유통·물류·재고,제품·서비스영업,영업관리·지원·영업기획,웹디자인,그래픽디자인·CG,출판·편집디자인,제품·산업디자인,광고·시각디자인,전시·공간디자인,건축·설계·인테리어,부동산·중개·분양·경매,요리·영양·제과제빵·바리스타", "dimension45":"[에그드랍] 골든하인드 인재 영입", "dimension46":"서울", "dimension65":"Y", "dimension66":"일반기업", "dimension70":"유료"}' data-gavirturl="https://www.jobkorea.co.kr/virtual/Recruit/GI_Read/39813773?Oem_Code=C1&amp;logpath=1" data-gino="42652189" data-gno="39813773" data-mem-sys="23187637" data-mem-type="C">
#  <div class="post">
#  <div class="post-list-corp">
#  <a class="name dev_view" href="/Recruit/GI_Read/39813773?Oem_Code=C1&amp;logpath=1" nav-src="/Search/_ContentsGIRead?Gno=39813773&amp;Mem_Type_Code=C&amp;Mem_Sys_No=23187637" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=39813773]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=39813773]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');">골든하인드</a>
#  <button class="btn-fav pseudo-icn-old lazyBg heart dev_favor-23187637 " onclick="GA_Event('통합검색_PC', '채용정보','관심_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">관심기업</button>
#  </div>
#  <div class="post-list-info">
#  <a class="title dev_view" href="/Recruit/GI_Read/39813773?Oem_Code=C1&amp;logpath=1" nav-src="/Search/_ContentsGIRead?Gno=39813773&amp;Mem_Type_Code=C&amp;Mem_Sys_No=23187637" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=39813773]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=39813773]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');">[에그드랍] 골든하인드 인재 영입</a>
#  <p class="option">
#  <span>신입·경력</span>
#  <span class="edu">학력무관</span>
#  <span>정규직</span>
#  <span class="loc short">서울</span>
#  <span class="loc long">서울 서초구 외</span>
#  <span class="date">~11/19(토)</span>
#  </p>
#  <p class="etc">제품개발, 법률자문, 원가설계, 음료개발, 점주상담, 점포 개발, 컴플라이언스, OEM, UI·UX디자인, 메뉴개발, 메뉴기획, 식품, 식품연구, 음식료, 점포개발, 퓨전푸드, 프랜차이즈, 패스트푸드, 기획, 변화관리, 전략, 조직관리, 교육, 급여관리, 보상·승진, 성과관리, 인사, 인사기획, 인사통합, 채용·면접, HRD, 결산, 관리회계, 전산회계, 회계, 결산, 재무, 재무기획, 재무회계, 물류, 원부자재관리, 무역, 무역사무, 무역중개인, 수출입무역, 통관, 구매관리, 상품입출고, 유통관리, 재고관리, SCM, 가맹점관리(SV), 상품기획, 신상품개발, MD, 가맹점영업, 국내영업, 법인영업, 식품영업, 해외영업, 가맹점관리, 거래처관리, 매출관리, 영업관리, 영업지원, 일러스트레이터, 포토샵, HTML, UI·UX디자인, 그래픽디자인, 일러스트레이터, 포토샵, 편집디자인(IBM), 편집디자인(MAC), 문구디자인, 패키지디자인, 광고디자인, 아트디렉터, 영상디자인, 크리에이티브디렉터, 실내디자인, 3DMax, 건축설계, 실내건축, 실내디자인, 인테리어, 인테리어설계, CAD, 공인중개사, 매입·매각, 부동산, 임대·임대컨설팅, 상가·사무실, 베이커리, 요리사, 조리사, 주방보조, 주방장, 푸드스타일리스트, Chef</p>
#  <button class="btn-scrap pseudo-icn-old lazyBg star dev_scrap-42652189 " data-brazeinfo="[에그드랍] 골든하인드 인재 영입|39813773|42652189|2022-09-30|2022-11-19|골든하인드|23187637" onclick="GA_Event('통합검색_PC', '채용정보','스크랩_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">스크랩</button>
#  </div>
#  <div class="post-list-apply">
#  <button class="btn-post-apply dev_direct_apply_list" onclick="GA_Event('통합검색_PC', '채용정보', '즉시지원');" type="button"><span>즉시지원</span></button>
#  </div>
#  </div>
#  </li>
#  <li class="list-post" data-gainfo='{"dimension42":"39990110", "dimension43":"전기·전자·제어,기계·기계설비", "dimension44":"기획·전략·경영,사무·총무·법무,재무·세무·IR,사무보조·문서작성,해외영업·무역영업,구매·자재,유통·물류·재고,제품·서비스영업,IT·솔루션·기술영업,영업관리·지원·영업기획,DBA·데이터베이스,웹기획·PM,빅데이터·AI(인공지능),생산관리·공정관리·품질관리,생산·제조·설비·조립,포장·가공,자동차·조선·기계,반도체·디스플레이,기계설계·CAD·CAM,시공·현장·감리·공무,설치·정비·A/S,연구소·R&amp;D", "dimension45":"각 분야별 신입/경력 직원모집 (생산/품질/공정/연구/설계/영업 외)", "dimension46":"서울, 경기, 인천", "dimension65":"Y", "dimension66":"일반기업", "dimension70":"유료"}' data-gavirturl="https://www.jobkorea.co.kr/virtual/Recruit/GI_Read/39990110?Oem_Code=C1&amp;logpath=1" data-gino="42811083" data-gno="39990110" data-mem-sys="36125" data-mem-type="C">
#  <div class="post">
#  <div class="post-list-corp">
#  <a class="name dev_view" href="/Recruit/GI_Read/39990110?Oem_Code=C1&amp;logpath=1" nav-src="/Search/_ContentsGIRead?Gno=39990110&amp;Mem_Type_Code=C&amp;Mem_Sys_No=36125" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=39990110]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=39990110]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');">윤성에프앤씨</a>
#  <button class="btn-fav pseudo-icn-old lazyBg heart dev_favor-36125 " onclick="GA_Event('통합검색_PC', '채용정보','관심_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">관심기업</button>
#  </div>
#  <div class="post-list-info">
#  <a class="title dev_view" href="/Recruit/GI_Read/39990110?Oem_Code=C1&amp;logpath=1" nav-src="/Search/_ContentsGIRead?Gno=39990110&amp;Mem_Type_Code=C&amp;Mem_Sys_No=36125" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=39990110]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=39990110]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');">각 분야별 신입/경력 직원모집 (생산/품질/공정/연구/설계/영업 외)</a>
#  <p class="option">
#  <span>신입·경력</span>
#  <span>정규직</span>
#  <span class="loc short">경기 외</span>
#  <span class="loc long">경기 안성시 외</span>
#  <span class="date">상시채용</span>
#  </p>
#  <p class="etc">자재입출고, 전기, PLC, 기계, 기계조립, CAD, CAM, 경영기획, 경영혁신, 서비스기획, 전략, 복리후생관리, 사무행정, 총무, 더존, 문서관리, 문서작성, 사무보조, 워드, 전산입력, 전산편집, 전산회계, 정보처리, 홈페이지관리, Excel, 내부통제, 세무, 자금, 자금조달, 재무기획, 재무회계, AICPA, 물류, 자재구매, 중국어, 해외영업, 구매관리, 자재관리, 자재구매, 국내영업, 기술영업, 일반영업, 기술영업, 네트워크영업, 솔루션영업, 거래선개발관리, 영업관리, 영업지원, 데이터베이스, 데이터마이닝, 웹기획, 웹서비스기획, PM, 인공지능(AI), 데이터분석, 공정, 공정관리, 생산, 생산관리, 품질, 품질검사, 품질관리, 금속, 기계, 기능직, 생산직, 설비, 연마, 용접, 절단, 제조, 조립, 기능직, 생산직, 포장, 기계, 생산기술, 기술직, 생산기술, 연구원, 전기·전자, 기계설계, 전기설계, 공무, 시공, 검사, 설치, 정비, A·S, 연구·실험·기술, 제조·공정</p>
#  <button class="btn-scrap pseudo-icn-old lazyBg star dev_scrap-42811083 " data-brazeinfo="각 분야별 신입/경력 직원모집 (생산/품질/공정/연구/설계/영업 외)|39990110|42811083|2022-10-17|2070-01-01|윤성에프앤씨|36125" onclick="GA_Event('통합검색_PC', '채용정보','스크랩_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">스크랩</button>
#  </div>
#  <div class="post-list-apply">
#  <button class="btn-post-apply dev_direct_apply_list" onclick="GA_Event('통합검색_PC', '채용정보', '즉시지원');" type="button"><span>즉시지원</span></button>
#  </div>
#  </div>
#  </li>
#  <li class="list-post" data-gainfo='{"dimension42":"40187906", "dimension43":"제약·보건·바이오", "dimension44":"기획·전략·경영,바이오·제약·식품,약사·한약사·약무보조", "dimension45":"[JW그룹] 2022년 6차 대졸 정규직 수시채용 [임상/연구개발/PV/경영관리]", "dimension46":"서울", "dimension65":"N", "dimension66":"일반기업", "dimension70":"무료"}' data-gavirturl="https://www.jobkorea.co.kr/virtual/Recruit/GI_Read/40187906?Oem_Code=C1&amp;logpath=1" data-gino="42989586" data-gno="40187906" data-mem-sys="38363963" data-mem-type="C">
#  <div class="post">
#  <div class="post-list-corp">
#  <a class="name dev_view" href="/Recruit/GI_Read/40187906?Oem_Code=C1&amp;logpath=1" nav-src="/Search/_ContentsGIRead?Gno=40187906&amp;Mem_Type_Code=C&amp;Mem_Sys_No=38363963" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=40187906]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=40187906]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');">JW홀딩스㈜</a>
#  <button class="btn-fav pseudo-icn-old lazyBg heart dev_favor-38363963 " onclick="GA_Event('통합검색_PC', '채용정보','관심_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">관심기업</button>
#  </div>
#  <div class="post-list-info">
#  <a class="title dev_view" href="/Recruit/GI_Read/40187906?Oem_Code=C1&amp;logpath=1" nav-src="/Search/_ContentsGIRead?Gno=40187906&amp;Mem_Type_Code=C&amp;Mem_Sys_No=38363963" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=40187906]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=40187906]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');">[JW그룹] 2022년 6차 대졸 정규직 수시채용 [임상/연구개발/PV/경영관리]</a>
#  <p class="option">
#  <span>신입·경력</span>
#  <span class="edu">대졸↑</span>
#  <span>정규직</span>
#  <span class="loc short">서울</span>
#  <span class="loc long">서울 서초구</span>
#  <span class="date">~11/15(화)</span>
#  </p>
#  <p class="etc">의료기기, 제약, 경영기획, 경영혁신, 기획, 기획조사, 사업기획, 바이오, 의료, 제약, 의약품, 제약PM, 제약연구개발, CRA</p>
#  <button class="btn-scrap pseudo-icn-old lazyBg star dev_scrap-42989586 " data-brazeinfo="[JW그룹] 2022년 6차 대졸 정규직 수시채용 [임상/연구개발/PV/경영관리]|40187906|42989586|2022-11-04|2022-11-15|JW홀딩스㈜|38363963" onclick="GA_Event('통합검색_PC', '채용정보','스크랩_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">스크랩</button>
#  </div>
#  <div class="post-list-apply">
#  <button class="btn-post-homepage dev_new_pop" onclick="_LA.EVT('5283');GA_Event('통합검색_PC', '채용정보', '홈페이지 지원');" src="/Recruit/GIReadHomepageLink?GI_NO=42989586" type="button"><span>홈페이지 지원</span></button>
#  </div>
#  </div>
#  </li>
#  <li class="list-post" data-gainfo='{"dimension42":"40114392", "dimension43":"백화점·유통·도소매", "dimension44":"비서·안내,전시·컨벤션,해외영업·무역영업,상품기획·MD,제품·서비스영업,영업관리·지원·영업기획,판매·서빙·매장관리,단순홍보·회원관리,아웃바운드TM,고객상담·인바운드,제품·산업디자인,의류·패션·잡화디자인,전시·공간디자인,여행·항공·숙박", "dimension45":"2022 LOUIS VUITTON 신입 및 경력 채용", "dimension46":"서울, 경기, 인천, 대전, 광주, 대구, 부산", "dimension65":"Y", "dimension66":"일반기업", "dimension70":"유료"}' data-gavirturl="https://www.jobkorea.co.kr/virtual/Recruit/GI_Read/40114392?Oem_Code=C1&amp;logpath=1" data-gino="42923482" data-gno="40114392" data-mem-sys="210641" data-mem-type="C">
#  <div class="post">
#  <div class="post-list-corp">
#  <a class="name dev_view" href="/Recruit/GI_Read/40114392?Oem_Code=C1&amp;logpath=1" nav-src="/Search/_ContentsGIRead?Gno=40114392&amp;Mem_Type_Code=C&amp;Mem_Sys_No=210641" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=40114392]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=40114392]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');">루이비통코리아</a>
#  <button class="btn-fav pseudo-icn-old lazyBg heart dev_favor-210641 " onclick="GA_Event('통합검색_PC', '채용정보','관심_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">관심기업</button>
#  </div>
#  <div class="post-list-info">
#  <a class="title dev_view" href="/Recruit/GI_Read/40114392?Oem_Code=C1&amp;logpath=1" nav-src="/Search/_ContentsGIRead?Gno=40114392&amp;Mem_Type_Code=C&amp;Mem_Sys_No=210641" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=40114392]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=40114392]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');">2022 LOUIS VUITTON 신입 및 경력 채용</a>
#  <p class="option">
#  <span>신입·경력</span>
#  <span>정규직 외</span>
#  <span class="loc short">서울 외</span>
#  <span class="loc long">서울 강남구 외</span>
#  <span class="date today">~11/11(금)</span>
#  </p>
#  <p class="etc">명품, VIP응대, 매니저, 면세점, 백화점, 리셉션, 비서, 수행비서, 안내, 안내데스크, 인포메이션, 임원비서, 전문비서, 컨시어지, 리셉션, 컨벤션, 바이어관리, 바이어상담, 영어, 중국어, 해외마케팅, 해외영업, MD, 상품기획, 상품입출고, 유통관리, 재고관리, 패션MD, MD, 국내영업, 일반영업, 해외영업, 화장품영업, 가맹점관리, 고객관리, 대리점관리, 매출관리, 영업관리, 영업지원, 계산원, 매장관리, 매출관리, 샵마스터, 예약, 의류판매, 잡화판매, 재고관리, 진열관리, 텔러, 판매관리, 판매영업, 화장품판매, 아웃바운드TM, 해피콜, 회원관리, 고객상담, 고객응대, 고객지원, 백화점, 인바운드TM, 인터넷쇼핑몰, 콜센터, CS, 고객관리, 단순홍보, 서비스홍보, 제품홍보, 홍보상담, 회원관리, 금속디자인, 섬유디자인, 악세사리디자인, 잡화디자인, 제품디자인, 주얼리디자인, 구두디자인, 남성정장, 남성캐주얼디자인, 넥타이디자인, 디스플레이, 매장디스플레이, 벨트디자인, 신발디자인, 악세사리디자인, 여성정장, 영캐주얼디자인, 의상디자인, 코디네이터, 피팅, 핸드백디자인, VMD, 공간디자인, 실내디자인, 면세점, 승무원, 안내, 컨시어지, 프런트, 예약·발권, 공항지상직</p>
#  <button class="btn-scrap pseudo-icn-old lazyBg star dev_scrap-42923482 " data-brazeinfo="2022 LOUIS VUITTON 신입 및 경력 채용|40114392|42923482|2022-10-31|2022-11-11|루이비통코리아|210641" onclick="GA_Event('통합검색_PC', '채용정보','스크랩_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">스크랩</button>
#  </div>
#  <div class="post-list-apply">
#  <button class="btn-post-apply dev_direct_apply_list" onclick="GA_Event('통합검색_PC', '채용정보', '즉시지원');" type="button"><span>즉시지원</span></button>
#  </div>
#  </div>
#  </li>
#  <li class="list-post" data-gainfo='{"dimension42":"40183970", "dimension43":"학원·어학원·교육원", "dimension44":"경리·회계·결산,구매·자재,상품기획·MD,아웃바운드TM,고객상담·인바운드,CS관리·강의,웹프로그래머,응용프로그래머,시스템프로그래머,웹기획·PM,컨텐츠·사이트운영,HTML·퍼블리싱·UI개발,ERP·시스템분석·설계,생산관리·공정관리·품질관리,화학·에너지·환경,그래픽디자인·CG,제품·산업디자인,광고·시각디자인,의류·패션·잡화디자인,전기·소방·통신·안전,유치원·보육교사,초중고·특수학교,교재기획·교수설계", "dimension45":"각 부문별 신입/경력 사원 채용", "dimension46":"경기", "dimension65":"Y", "dimension66":"일반기업", "dimension70":"유료"}' data-gavirturl="https://www.jobkorea.co.kr/virtual/Recruit/GI_Read/40183970?Oem_Code=C1&amp;logpath=1" data-gino="42986037" data-gno="40183970" data-mem-sys="31749" data-mem-type="C">
#  <div class="post">
#  <div class="post-list-corp">
#  <a class="name dev_view" href="/Recruit/GI_Read/40183970?Oem_Code=C1&amp;logpath=1" nav-src="/Search/_ContentsGIRead?Gno=40183970&amp;Mem_Type_Code=C&amp;Mem_Sys_No=31749" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=40183970]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=40183970]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');">㈜모나미</a>
#  <button class="btn-fav pseudo-icn-old lazyBg heart dev_favor-31749 " onclick="GA_Event('통합검색_PC', '채용정보','관심_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">관심기업</button>
#  </div>
#  <div class="post-list-info">
#  <a class="title dev_view" href="/Recruit/GI_Read/40183970?Oem_Code=C1&amp;logpath=1" nav-src="/Search/_ContentsGIRead?Gno=40183970&amp;Mem_Type_Code=C&amp;Mem_Sys_No=31749" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=40183970]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=40183970]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');">각 부문별 신입/경력 사원 채용</a>
#  <p class="option">
#  <span>신입·경력</span>
#  <span class="edu">고졸↑</span>
#  <span>정규직</span>
#  <span class="loc short">경기</span>
#  <span class="loc long">경기 용인시 외</span>
#  <span class="date">~11/13(일)</span>
#  </p>
#  <p class="etc">학원강사, 경영지원, 물류관리, 물류센터, 상품기획, 고객상담, 고객응대, 고객지원, CS, 콜센터운영, 콜통계분석, 고객문의분석, 모바일기획, 웹기획, 웹서비스기획, 정보설계, 제안·컨설팅, 컨텐츠기획, 통계·로그분석, PM, UI설계, 웹프로그래머, HTML, Java, jsp, MS-SQL, MySQL, SQL, 아이폰, 안드로이드, 응용프로그래머, 전산전공, ABAP, API, Application, ASP.NET, C, C#, C++, Java, Linux, Oracle, Python, SQL, Windows, WindowsMobile, 시스템프로그래머, 컨텐츠개발, 웹접근성, 웹표준, 모델링, 시스템분석, 시스템설계, 시스템엔지니어, 요구분석, 튜닝, DBA, PM, 생산, 생산관리, QA, 생산기술, 연구관리, 연구원, 화학, R&amp;D, 그래픽디자인, 시각디자인, 일러스트레이터, 포토샵, 공업디자인, 문구디자인, 산업디자인, 악세사리디자인, 잡화디자인, 제품디자인, 패키지디자인, 팬시디자인, 디지털디자인, 시각디자인, 잡화디자인, 공조냉동, 기계설비, 시설관리, 열관리, 교수설계, 교육기획, 교재컨텐츠개발, 교육프로그램</p>
#  <button class="btn-scrap pseudo-icn-old lazyBg star dev_scrap-42986037 " data-brazeinfo="각 부문별 신입/경력 사원 채용|40183970|42986037|2022-11-04|2022-11-13|㈜모나미|31749" onclick="GA_Event('통합검색_PC', '채용정보','스크랩_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">스크랩</button>
#  </div>
#  <div class="post-list-apply">
#  <button class="btn-post-apply dev_direct_apply_list" onclick="GA_Event('통합검색_PC', '채용정보', '즉시지원');" type="button"><span>즉시지원</span></button>
#  </div>
#  </div>
#  </li>
#  <li class="list-post" data-gainfo='{"dimension42":"40150236", "dimension43":"제약·보건·바이오", "dimension44":"기획·전략·경영,인사·노무·교육,경리·회계·결산,재무·세무·IR,마케팅·광고·분석,제품·서비스영업,영업관리·지원·영업기획,법인영업,네트워크·서버·보안,생산관리·공정관리·품질관리,바이오·제약·식품,시공·현장·감리·공무,전기·소방·통신·안전,시설·보안·경비·안전,사무·원무·코디", "dimension45":"2022년 11월 한미약품그룹 수시채용", "dimension46":"서울, 제주", "dimension65":"N", "dimension66":"일반기업", "dimension70":"유료"}' data-gavirturl="https://www.jobkorea.co.kr/virtual/Recruit/GI_Read/40150236?Oem_Code=C1&amp;logpath=1" data-gino="42955515" data-gno="40150236" data-mem-sys="198704" data-mem-type="C">
#  <div class="post">
#  <div class="post-list-corp">
#  <a class="name dev_view" href="/Recruit/GI_Read/40150236?Oem_Code=C1&amp;logpath=1" nav-src="/Search/_ContentsGIRead?Gno=40150236&amp;Mem_Type_Code=C&amp;Mem_Sys_No=198704" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=40150236]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=40150236]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');">한미약품(주)</a>
#  <button class="btn-fav pseudo-icn-old lazyBg heart dev_favor-198704 " onclick="GA_Event('통합검색_PC', '채용정보','관심_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">관심기업</button>
#  </div>
#  <div class="post-list-info">
#  <a class="title dev_view" href="/Recruit/GI_Read/40150236?Oem_Code=C1&amp;logpath=1" nav-src="/Search/_ContentsGIRead?Gno=40150236&amp;Mem_Type_Code=C&amp;Mem_Sys_No=198704" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=40150236]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=40150236]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');">2022년 11월 한미약품그룹 수시채용</a>
#  <p class="option">
#  <span>신입·경력</span>
#  <span class="edu">대졸↑</span>
#  <span>정규직</span>
#  <span class="loc short">서울 외</span>
#  <span class="loc long">서울 송파구 외</span>
#  <span class="date">~11/13(일)</span>
#  </p>
#  <p class="etc">제약, 경영기획, 기획, 기획조사, 변화관리, 사업기획, 인수·합병, 전략, 노무, 보상·승진, 인사, 인사기획, 채용·면접, 결산, 세무, 회계, 회계감사, SAP, 감사, 결산, 세무, 재무회계, 국제회의, 라이센싱, 마케팅, 마케팅기획, 브랜딩, 시장분석, 퍼블리싱, CMO, IMC, BM, 가맹점영업, 국내영업, 법인영업, 일반영업, 제약영업, 가맹점관리, 거래선개발관리, 거래처관리, 고객관리, 납품관리, 대리점관리, 매출관리, 영업관리, 영업기획, 영업지원, 외주관리, 법인영업, 일반영업, 제약영업, 네트워크관리, 네트워크엔지니어, 보안관리, 보안관제, 보안기술, 정보보안, 안전, 바이오, 의료, 제약, 식품가공·개발, 의약품, 미생물, 임상개발, 유전공학, 제약PM, 소방감리, 산업안전, 소방설비, 안전, 소방·방재, 산업안전, 산업안전기사, 소방, 안전, 보험심사·청구</p>
#  <button class="btn-scrap pseudo-icn-old lazyBg star dev_scrap-42955515 " data-brazeinfo="2022년 11월 한미약품그룹 수시채용|40150236|42955515|2022-11-02|2022-11-13|한미약품(주)|198704" onclick="GA_Event('통합검색_PC', '채용정보','스크랩_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">스크랩</button>
#  </div>
#  <div class="post-list-apply">
#  <button class="btn-post-homepage dev_new_pop" onclick="_LA.EVT('5283');GA_Event('통합검색_PC', '채용정보', '홈페이지 지원');" src="/Recruit/GIReadHomepageLink?GI_NO=42955515" type="button"><span>홈페이지 지원</span></button>
#  </div>
#  </div>
#  </li>
#  <li class="list-post" data-gainfo='{"dimension42":"40139877", "dimension43":"쇼핑몰·오픈마켓·소셜커머스,식품가공,백화점·유통·도소매,무역·상사", "dimension44":"기획·전략·경영,사무·총무·법무,인사·노무·교육,경리·회계·결산,마케팅·광고·분석,해외영업·무역영업,수출입·무역사무,구매·자재,상품기획·MD,유통·물류·재고,배송·택배·운송,제품·서비스영업,영업관리·지원·영업기획,법인영업,고객상담·인바운드,웹디자인,소프트웨어·하드웨어,생산관리·공정관리·품질관리,생산·제조·설비·조립,바이오·제약·식품,출판·편집디자인,제품·산업디자인,인쇄·출판·편집,시설·보안·경비·안전,법률·특허·상표", "dimension45":"2022년 하반기 각 부문 신입/경력사원 모집", "dimension46":"서울, 경기", "dimension65":"Y", "dimension66":"일반기업", "dimension70":"유료"}' data-gavirturl="https://www.jobkorea.co.kr/virtual/Recruit/GI_Read/40139877?Oem_Code=C1&amp;logpath=1" data-gino="42945946" data-gno="40139877" data-mem-sys="42900" data-mem-type="C">
#  <div class="post">
#  <div class="post-list-corp">
#  <a class="name dev_view" href="/Recruit/GI_Read/40139877?Oem_Code=C1&amp;logpath=1" nav-src="/Search/_ContentsGIRead?Gno=40139877&amp;Mem_Type_Code=C&amp;Mem_Sys_No=42900" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=40139877]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=40139877]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');">㈜한국생활건강</a>
#  <button class="btn-fav pseudo-icn-old lazyBg heart dev_favor-42900 " onclick="GA_Event('통합검색_PC', '채용정보','관심_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">관심기업</button>
#  </div>
#  <div class="post-list-info">
#  <a class="title dev_view" href="/Recruit/GI_Read/40139877?Oem_Code=C1&amp;logpath=1" nav-src="/Search/_ContentsGIRead?Gno=40139877&amp;Mem_Type_Code=C&amp;Mem_Sys_No=42900" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=40139877]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=40139877]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');">2022년 하반기 각 부문 신입/경력사원 모집</a>
#  <p class="option">
#  <span>신입·경력</span>
#  <span class="edu">학력무관</span>
#  <span>정규직</span>
#  <span class="loc short">경기 외</span>
#  <span class="loc long">경기 안성시 외</span>
#  <span class="date">~11/30(수)</span>
#  </p>
#  <p class="etc">홈쇼핑, 쇼핑몰, 건강식품, 기획조사, 사업기획, 사업제휴, 신규사업·BD, 타당성분석, 법무, 비품관리, 사무행정, 자산관리, 총무, 노사관리, 보상·승진, 인사, 인사기획, 인사통합, 인재개발, 임금관리, HRM, 결산, 더존, 부가세신고, 전산회계, 회계, ERP운용, 마케팅, 마케팅기획, 바이럴마케팅, 브랜딩, 물류, 자재관리, 자재구매기획, 창고관리, 무역일반, 바이어상담, 영어, 중국어, 해외영업, 무역사무, 무역영어, 물류, 물류관리, 구매관리, 물류관리, 상품입출고, 유통관리, 자재관리, 재고관리, SCM, 리테일MD, 상품기획, 상품입출고, 식품MD, 신상품개발, 온라인MD, 유통관리, MD, AMD, 가맹점영업, 국내영업, 식품영업, 일반영업, 영업지원, 납품영업, 법인영업, 일반영업, 고객상담, 고객응대, 고객지원, 인터넷쇼핑몰, CS, 일러스트레이터, 포토샵, HTML, UI·UX디자인, 유지보수, 하드웨어, 소프트웨어, 품질, 품질검사, 품질관리, 품질보증, HACCP, QA, 설비, 식품, 식품가공·개발, 편집디자인(IBM), 편집디자인(MAC), 패키지디자인, 인쇄, 편집, 산업안전, 법률서비스, 법무사, 법학전공, 변호사, 소송·민사·등기</p>
#  <button class="btn-scrap pseudo-icn-old lazyBg star dev_scrap-42945946 " data-brazeinfo="2022년 하반기 각 부문 신입/경력사원 모집|40139877|42945946|2022-11-01|2022-11-30|㈜한국생활건강|42900" onclick="GA_Event('통합검색_PC', '채용정보','스크랩_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">스크랩</button>
#  </div>
#  <div class="post-list-apply">
#  <button class="btn-post-apply dev_direct_apply_list" onclick="GA_Event('통합검색_PC', '채용정보', '즉시지원');" type="button"><span>즉시지원</span></button>
#  </div>
#  </div>
#  </li>
#  <li class="list-post" data-gainfo='{"dimension42":"40183875", "dimension43":"백화점·유통·도소매", "dimension44":"비서·안내,영업관리·지원·영업기획,판매·서빙·매장관리,단순홍보·회원관리,고객상담·인바운드,요리·영양·제과제빵·바리스타", "dimension45":"[롯데백화점] 22년 하반기 서비스전문직 채용", "dimension46":"서울, 경기, 인천, 경북, 부산, 울산, 경남", "dimension65":"N", "dimension66":"일반기업", "dimension70":"유료"}' data-gavirturl="https://www.jobkorea.co.kr/virtual/Recruit/GI_Read/40183875?Oem_Code=C1&amp;logpath=1" data-gino="42985944" data-gno="40183875" data-mem-sys="35561921" data-mem-type="C">
#  <div class="post">
#  <div class="post-list-corp">
#  <a class="name dev_view" href="/Recruit/GI_Read/40183875?Oem_Code=C1&amp;logpath=1" nav-src="/Search/_ContentsGIRead?Gno=40183875&amp;Mem_Type_Code=C&amp;Mem_Sys_No=35561921" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=40183875]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=40183875]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');">롯데쇼핑</a>
#  <button class="btn-fav pseudo-icn-old lazyBg heart dev_favor-35561921 " onclick="GA_Event('통합검색_PC', '채용정보','관심_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">관심기업</button>
#  </div>
#  <div class="post-list-info">
#  <a class="title dev_view" href="/Recruit/GI_Read/40183875?Oem_Code=C1&amp;logpath=1" nav-src="/Search/_ContentsGIRead?Gno=40183875&amp;Mem_Type_Code=C&amp;Mem_Sys_No=35561921" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=40183875]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=40183875]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');">[롯데백화점] 22년 하반기 서비스전문직 채용</a>
#  <p class="option">
#  <span>신입·경력</span>
#  <span class="edu">고졸↑</span>
#  <span>계약직</span>
#  <span class="loc short">서울 외</span>
#  <span class="loc long">서울 중구 외</span>
#  <span class="date">~11/13(일)</span>
#  </p>
#  <p class="etc">안내, 안내데스크, 고객관리, 매출관리, 매출관리, 판매관리, 홀써빙, 고객상담, 고객응대, 고객지원, 백화점, CS, 고객관리, 바리스타</p>
#  <button class="btn-scrap pseudo-icn-old lazyBg star dev_scrap-42985944 " data-brazeinfo="[롯데백화점] 22년 하반기 서비스전문직 채용|40183875|42985944|2022-11-04|2022-11-13|롯데쇼핑|35561921" onclick="GA_Event('통합검색_PC', '채용정보','스크랩_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">스크랩</button>
#  </div>
#  <div class="post-list-apply">
#  <button class="btn-post-homepage dev_new_pop" onclick="_LA.EVT('5283');GA_Event('통합검색_PC', '채용정보', '홈페이지 지원');" src="/Recruit/GIReadHomepageLink?GI_NO=42985944" type="button"><span>홈페이지 지원</span></button>
#  </div>
#  </div>
#  </li>
#  </ul>
#  </div>
#  <?xml version="1.0" encoding="utf-16"?>
#  <div class="tplPagination newVer wide">
#  <ul>
#  <li>
#  <span class="now">1</span>
#  </li>
#  </ul>
#  </div><?xml version="1.0" encoding="utf-16"?>
#  <div class="tplPagination newVer short clear">
#  <ul class="clear">
#  <li>
#  <span class="now">1</span>
#  </li>
#  <li>
#  <span class="pgTotal">1</span>
#  </li>
#  </ul>
#  </div> <p class="copyright">© <strong><a href="http://company.jobkorea.co.kr/" target="_blank">JOBKOREA</a></strong> LLC. All rights reserved.</p>
#  </div>
#  </div>
#  </div>]

# %%
len(soup.select('.recruit-info'))
# Out:
# 1

# %%
ss = soup.select('.recruit-info')[0].select('.lists')
len(ss)
# Out:
# 1

# %%
len(ss[0].select('.post'))
# Out:
# 21

# %%
ss[0].select('.post')[10]
# Out:
# <div class="post">
# <div class="post-list-corp">
# <a class="name dev_view" href="/Recruit/GI_Read/39911204?Oem_Code=C1&amp;logpath=1&amp;stext=data science&amp;listno=11" nav-src="/Search/_ContentsGIRead?Gno=39911204&amp;Mem_Type_Code=C&amp;Mem_Sys_No=27127417" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=39911204]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=39911204]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="지니너스㈜">지니너스㈜</a>
# <button class="btn-fav pseudo-icn-old lazyBg heart dev_favor-27127417 " onclick="GA_Event('통합검색_PC', '채용정보','관심_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">관심기업</button>
# </div>
# <div class="post-list-info">
# <a class="title dev_view" href="/Recruit/GI_Read/39911204?Oem_Code=C1&amp;logpath=1&amp;stext=data science&amp;listno=11" nav-src="/Search/_ContentsGIRead?Gno=39911204&amp;Mem_Type_Code=C&amp;Mem_Sys_No=27127417" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=39911204]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=39911204]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="지니너스㈜ 신입/경력 수시채용">
#                                 지니너스㈜ 신입/경력 수시채용
#                             </a>
# <p class="option">
# <span class="exp">신입·경력</span>
# <span class="edu">학력무관</span>
# <span>정규직 외</span>
# <span class="loc short">서울</span>
# <span class="loc long">서울 송파구</span>
# <span class="date today">~11/11(금)</span>
# </p>
# <p class="etc">R, 세포 배양, 클라우드 컴퓨팅, AI, DNA, FACS, ELISA, EMR, Docker, GMP, ISO13485, KGMP, json, Microarray, ML, NGS, MVC, QC, QMS, SCI, Shell Script, Trobleshooting, RNA Prep, 전사체, Cell-free DNA, 면역 세포 분리, SCIE, 단일세포 전사체 분석, NGS 데이터, 유전체 데이터 생산, ELISpot, FACS 분석, 면역 세포 배양, mRNA transfection, 임상검체 DNA, DTC 유전자검사 마케팅, 조직생검 유래 암 유전체 데이터 분석, IVDR, 바이오, 생명공학, 경영기획, 기획, 기획조사, 사업기획, 사업제휴, 서비스기획, 신규사업·BD, 전략, 조직관리, 타당성분석, 관리, 문서관리, 사무행정, 교육, 인사, 채용·면접, HRD, 자금, 주식IR, 마케팅, 마케팅기획, 브랜딩, 소셜미디어, 시장분석, 홍보, SNS운영, 영어, 해외마케팅, 해외영업, 구매관리, 자재구매기획, 재고관리, 웹기획, 온라인마케팅, 웹마케팅, 웹프로그래머, Java, MySQL, Python, API, Java, Python, 시스템분석, 시스템엔지니어, Python, 생산관리, 품질관리, 기술연구소, 생명공학, 실험, 연구원, R&amp;D, 바이오, 세포배양, 유전공학</p>
# <button class="btn-scrap pseudo-icn-old lazyBg star dev_scrap-42740242 " data-brazeinfo="지니너스㈜ 신입/경력 수시채용|39911204|42740242|yyyy-MM-dd|yyyy-MM-dd|지니너스㈜|27127417" onclick="GA_Event('통합검색_PC', '채용정보','스크랩_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">스크랩</button>
# </div>
# <div class="post-list-apply">
# <button class="btn-post-apply dev_direct_apply_list" onclick="GA_Event('통합검색_PC', '채용정보', '즉시지원');" type="button"><span>즉시지원</span></button>
# </div>
# </div>

# %%
ss[0].select('.post')[0].select('.post-list-info')[0].a.text.strip()
# Out:
# '[모아소프트] AI/Data Science연구소 소프트웨어 개발인력 구인'

# %%
s0 = ss[0].select('.post')[0].select('.post-list-corp')
corp = s0[0].a.text
s0 = ss[0].select('.post')[0].select('.post-list-info')
title = s0[0].a.text.strip()
loc = s0[0].select('.loc.long')[0].text
date = s0[0].select('.date')[0].text
etc = s0[0].select('.etc')[0].text

# %%
corp, title, loc, date, etc
# Out:
# ('㈜모아소프트',
#  '[모아소프트] AI/Data Science연구소 소프트웨어 개발인력 구인',
#  '서울 송파구',
#  '상시채용',
#  '소프트웨어개발, 솔루션, C, C++, Java, Python')

# %%
ss = soup.select('.recruit-info')[0].select('.lists')
post = ss[0].select('.post')
print("There are a total of {} job postings.".format(len(post)))

corps, titles, locs, dates, etcs = [], [], [], [], []
for i in range(len(post)):
    s0 = post[i].select('.post-list-corp')
    corps.append(s0[0].a.text)
    s0 = post[i].select('.post-list-info')
    titles.append(s0[0].a.text.strip())
    locs.append(s0[0].select('.loc.long')[0].text)
    dates.append(s0[0].select('.date')[0].text)
    etcs.append(s0[0].select('.etc')[0].text)
# Out:
# There are a total of 21 job postings.

# %%
pd.DataFrame(np.c_[corps, titles, locs, dates, etcs],
             columns=["corps", "titles", "locs", "dates", "etcs"])
# Out:
#                         corps                                         titles  \
# 0                      ㈜모아소프트       [모아소프트] AI/Data Science연구소 소프트웨어 개발인력 구인
# 1                      ㈜엔씨소프트                 [엔씨소프트]빅데이터 플랫폼 관리도구(웹) 개발자 모집
# 2                지식시스템㈜ KSTEC      [KSTEC] Optimization & AI 기술융합 신입 컨설턴트 모집
# 3                지식시스템㈜ KSTEC      [KSTEC] Prescriptive Analytics 컨설턴트 신입 채용
# 4                    에타일렉트로닉스             인공지능(AI), 데이터 사이언스 (알고리즘 개발) 팀원 모집
# 5                        ㈜넷타겟                              (주)넷타겟 각 부문별 수시채용
# 6       ㈜크레버스(Creverse, Inc.)                    [경력/정규직] 코딩 콘텐츠 기획 및 개발자 모집
# 7   SAS Software Korea Ltd Co        Recruitment Analytical Consultant (SAS)
# 8                         ㈜폼즈       [신입/경력] python을 활용한 Ai개발 및 프론트 백앤드개발자 모집
# 9                       지니너스㈜                             지니너스㈜ 신입 및 경력 수시채용
# 10                      지니너스㈜                               지니너스㈜ 신입/경력 수시채용
# 11                캐논코리아 주식회사              2023년 1분기 캐논코리아 정기신입사원(채용연계형인턴) 모집
# 12                   ㈜신세계아이앤씨   신세계아이앤씨 SW개발/운영, 기획, 클라우드, AI, 영업, 보안 경력직 모집
# 13                      골든하인드                             [에그드랍] 골든하인드 인재 영입
# 14                     윤성에프앤씨         각 분야별 신입/경력 직원모집 (생산/품질/공정/연구/설계/영업 외)
# 15                     JW홀딩스㈜  [JW그룹] 2022년 6차 대졸 정규직 수시채용 [임상/연구개발/PV/경영관리]
# 16                    루이비통코리아                  2022 LOUIS VUITTON 신입 및 경력 채용
# 17                       ㈜모나미                              각 부문별 신입/경력 사원 채용
# 18                    한미약품(주)                          2022년 11월 한미약품그룹 수시채용
# 19                    ㈜한국생활건강                      2022년 하반기 각 부문 신입/경력사원 모집
# 20                       롯데쇼핑                      [롯데백화점] 22년 하반기 서비스전문직 채용
#
#         locs      dates                                               etcs
# 0     서울 송파구       상시채용                 소프트웨어개발, 솔루션, C, C++, Java, Python
# 1     경기 성남시  ~11/25(금)  프로그램개발, RDBMS, 3D온라인게임, 게임개발, 게임기획, 게임디자인, 게임소...
# 2   경기 성남시 외  ~11/30(수)  ERP, SCM, 시스템분석설계, APS, DB, 소프트웨어개발, 솔루션, 데이터베...
# 3   경기 성남시 외  ~11/30(수)  ERP, SCM, 시스템분석설계, APS, DB, 데이터베이스, DBA, 응용프로그...
# 4     서울 용산구       상시채용  전자회로, Firmware, Hardware, PCB, SMPS, Python, 인...
# 5   대전 유성구 외       상시채용  바이오, 기획, 전략, 마케팅, 마케팅기획, 바이럴마케팅, 국내영업, 해외영업, 웹...
# 6     서울 강남구       상시채용         어학원, 컨텐츠개발, C, Java, Python, 컨텐츠개발, 프로그램강의
# 7     서울 서초구       상시채용  SAS, 솔루션, BI, BigData, DataMining, DW, Python,...
# 8   서울 구로구 외       상시채용                                    소프트웨어개발, Python
# 9     서울 송파구  ~02/06(월)  세포 배양, DNA, GMP, NGS, RNA Prep, 면역 세포 분리, 단일세포...
# 10    서울 송파구  ~11/11(금)  R, 세포 배양, 클라우드 컴퓨팅, AI, DNA, FACS, ELISA, EMR,...
# 11  경기 안산시 외  ~11/20(일)  기계, 경영기획, 기획, 기획조사, 전략, 홈페이지관리, 결산, 원가, 원가회계, ...
# 12   서울 중구 외       상시채용  모바일앱개발, 소프트웨어개발, 솔루션, asp, BigData, CRM, SI, W...
# 13  서울 서초구 외  ~11/19(토)  제품개발, 법률자문, 원가설계, 음료개발, 점주상담, 점포 개발, 컴플라이언스, O...
# 14  경기 안성시 외       상시채용  자재입출고, 전기, PLC, 기계, 기계조립, CAD, CAM, 경영기획, 경영혁신...
# 15    서울 서초구  ~11/15(화)  의료기기, 제약, 경영기획, 경영혁신, 기획, 기획조사, 사업기획, 바이오, 의료,...
# 16  서울 강남구 외  ~11/11(금)  명품, VIP응대, 매니저, 면세점, 백화점, 리셉션, 비서, 수행비서, 안내, 안...
# 17  경기 용인시 외  ~11/13(일)  학원강사, 경영지원, 물류관리, 물류센터, 상품기획, 고객상담, 고객응대, 고객지원...
# 18  서울 송파구 외  ~11/13(일)  제약, 경영기획, 기획, 기획조사, 변화관리, 사업기획, 인수·합병, 전략, 노무,...
# 19  경기 안성시 외  ~11/30(수)  홈쇼핑, 쇼핑몰, 건강식품, 기획조사, 사업기획, 사업제휴, 신규사업·BD, 타당성...
# 20   서울 중구 외  ~11/13(일)  안내, 안내데스크, 고객관리, 매출관리, 매출관리, 판매관리, 홀써빙, 고객상담, ...

# %% [markdown]
# # Exercise
# - old example
# - they changed the webpage and it no longer works. (2022/9)
# - showing his code just for your reference

# %%
'''
# put altogether
url = 'https://kr.indeed.com/jobs?q=data+science&l=%EC%84%9C%EC%9A%B8%ED%8A%B9%EB%B3%84%EC%8B%9C'
link = requests.get(url)
soup = BeautifulSoup(link.text, 'html.parser')

job_elems = soup.select('.resultContent') # class

for i in job_elems:
    title = i.find('h2')
    company = i.find('span', class_='companyName')
    location = i.find('div', class_='companyLocation')
    
    if None in (title, company, location):
        continue
        
    print(title.text.strip())
    print(company.text.strip())
    print(location.text.strip())
'''
# Out:
# "\n# put altogether\nurl = 'https://kr.indeed.com/jobs?q=data+science&l=%EC%84%9C%EC%9A%B8%ED%8A%B9%EB%B3%84%EC%8B%9C'\nlink = requests.get(url)\nsoup = BeautifulSoup(link.text, 'html.parser')\n\njob_elems = soup.select('.resultContent') # class\n\nfor i in job_elems:\n    title = i.find('h2')\n    company = i.find('span', class_='companyName')\n    location = i.find('div', class_='companyLocation')\n    \n    if None in (title, company, location):\n        continue\n        \n    print(title.text.strip())\n    print(company.text.strip())\n    print(location.text.strip())\n"

# %%
# .text and .string
html_text = """
<html>
<body>
  <td>some text</td>
  <td></td>
  <td><p>more text</p></td>
  <td>even <p>more text</p></td>"
</body>
</html>
"""
soup = BeautifulSoup(html_text, 'html.parser')

# %%
soup.find_all('td')
# Out:
# [<td>some text</td>,
#  <td></td>,
#  <td><p>more text</p></td>,
#  <td>even <p>more text</p></td>]

# %%
for i in soup.find_all('td'):
    print(i.string)
# Out:
# some text
# None
# more text
# None

# %%
for i in soup.find_all('td'):
    print(i.text)
# Out:
# some text
#
# more text
# even more text
